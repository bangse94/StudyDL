# %% [markdown]
# <a href="https://colab.research.google.com/github/bangse94/StudyDL/blob/main/DCGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### 라이브러리 및 데이터 불러오기
# 필요한 라이브러리를 불러온다.
import torch
import torch.nn as nn
from torch.optim import Adam
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.autograd import Variable
import pickle

# 데이터 전처리 방식을 지정한다.
transform = transforms.Compose([
        transforms.ToTensor(), # 데이터를 PyTorch의 Tensor 형식으로 바꾼다.
        transforms.Normalize(mean=(0.5,), std=(0.5,)) # 픽셀값 0 ~ 1 -> -1 ~ 1
])

# MNIST 데이터셋을 불러온다. 지정한 폴더에 없을 경우 자동으로 다운로드한다.
mnist = datasets.MNIST(root='data', download=True, transform=transform)

# 데이터를 한번에 batch_size만큼만 가져오는 dataloader를 만든다.
dataloader = DataLoader(mnist, batch_size=60, shuffle=True)

# %%
import os
import imageio

if torch.cuda.is_available():
    use_gpu = True
leave_log = True
if leave_log:
    result_dir = 'DCGAN_generated_images'
    if not os.path.isdir(result_dir):
        os.mkdir(result_dir)

# %%
### DCGAN의 생성자
class Generator(nn.Module):
    
    # 네트워크 구조
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            nn.ConvTranspose2d(in_channels=100, out_channels=28*8, 
                               kernel_size=7, stride=1, padding=0, 
                               bias=False),
            nn.BatchNorm2d(num_features=28*8),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(in_channels=28*8, out_channels=28*4, 
                               kernel_size=4, stride=2, padding=1, 
                               bias=False),
            nn.BatchNorm2d(num_features=28*4),
            nn.ReLU(True),
            nn.ConvTranspose2d(in_channels=28*4, out_channels=1, 
                               kernel_size=4, stride=2, padding=1, 
                               bias=False),
            nn.Tanh())
        
    # (batch_size x 100) 크기의 랜덤 벡터를 받아 
    # 이미지를 (batch_size x 1 x 28 x 28) 크기로 출력한다.
    def forward(self, inputs):
        inputs = inputs.view(-1, 100, 1, 1)
        return self.main(inputs)

# %%
### DCGAN의 구분자
class Discriminator(nn.Module):
    
    # 네트워크 구조
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=28*4, 
                      kernel_size=4, stride=2, padding=1, 
                      bias=False),
            nn.BatchNorm2d(num_features=28*4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(in_channels=28*4, out_channels=28*8, 
                      kernel_size=4, stride=2, padding=1, 
                      bias=False),
            nn.BatchNorm2d(num_features=28*8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(in_channels=28*8, out_channels=1, 
                      kernel_size=7, stride=1, padding=0, 
                      bias=False),
            nn.Sigmoid())
        
    # (batch_size x 1 x 28 x 28) 크기의 이미지를 받아
    # 이미지가 진짜일 확률을 0~1 사이로 출력한다.
    def forward(self, inputs):
        o = self.main(inputs)
        return o.view(-1, 1)

# %%
### 생성자와 구분자 객체 만들기
G = Generator()
D = Discriminator()

if use_gpu:
    G.cuda()
    D.cuda()

# %%
### 손실 함수와 최적화 기법 지정하기
# Binary Cross Entropy loss
criterion = nn.BCELoss()

# 생성자의 매개 변수를 최적화하는 Adam optimizer
G_optimizer = Adam(G.parameters(), lr=0.0002, betas=(0.5, 0.999))
# 구분자의 매개 변수를 최적화하는 Adam optimizer
D_optimizer = Adam(D.parameters(), lr=0.0002, betas=(0.5, 0.999))

# %%
# 학습 결과 시각화하기
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

def square_plot(data, path):
    """Take an array of shape (n, height, width) or (n, height, width , 3)
       and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)"""

    if type(data) == list:
	    data = np.concatenate(data)
    # normalize data for display
    data = (data - data.min()) / (data.max() - data.min())

    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))

    padding = (((0, n ** 2 - data.shape[0]) ,
                (0, 1), (0, 1))  # add some space between filters
               + ((0, 0),) * (data.ndim - 3))  # don't pad the last dimension (if there is one)
    data = np.pad(data , padding, mode='constant' , constant_values=1)  # pad with ones (white)

    # tilethe filters into an image
    data = data.reshape((n , n) + data.shape[1:]).transpose((0 , 2 , 1 , 3) + tuple(range(4 , data.ndim + 1)))

    data = data.reshape((n * data.shape[1] , n * data.shape[3]) + data.shape[4:])

    plt.imsave(path, data, cmap='gray')

# %%
if leave_log:
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    generated_images = []
    
z_fixed = Variable(torch.randn(5 * 5, 100), volatile=True)
if use_gpu:
    z_fixed = z_fixed.cuda()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   import sys

# %%
### 모델 학습을 위한 반복문
# 데이터셋을 100번 돌며 학습한다.
for epoch in range(100):
    
    if leave_log:
        D_losses = []
        G_losses = []
    
    # 한번에 batch_size만큼 데이터를 가져온다.
    for real_data, _ in dataloader:
        batch_size = real_data.size(0)
        
        # 데이터를 pytorch의 변수로 변환한다.
        real_data = Variable(real_data)

        ### 구분자 학습시키기

        # 이미지가 진짜일 때 정답 값은 1이고 가짜일 때는 0이다.
        # 정답지에 해당하는 변수를 만든다.
        target_real = Variable(torch.ones(batch_size, 1))
        target_fake = Variable(torch.zeros(batch_size, 1))
         
        if use_gpu:
            real_data, target_real, target_fake = real_data.cuda(), target_real.cuda(), target_fake.cuda()
            
        # 진짜 이미지를 구분자에 넣는다.
        D_result_from_real = D(real_data)
        # 구분자의 출력값이 정답지인 1에서 멀수록 loss가 높아진다.
        D_loss_real = criterion(D_result_from_real, target_real)

        # 생성자에 입력으로 줄 랜덤 벡터 z를 만든다.
        z = Variable(torch.randn((batch_size, 100)))
        
        if use_gpu:
            z = z.cuda()
            
        # 생성자로 가짜 이미지를 생성한다.
        fake_data = G(z)
        
        # 생성자가 만든 가짜 이미지를 구분자에 넣는다.
        D_result_from_fake = D(fake_data)
        # 구분자의 출력값이 정답지인 0에서 멀수록 loss가 높아진다.
        D_loss_fake = criterion(D_result_from_fake, target_fake)
        
        # 구분자의 loss는 두 문제에서 계산된 loss의 합이다.
        D_loss = D_loss_real + D_loss_fake
        
        # 구분자의 매개 변수의 미분값을 0으로 초기화한다.
        D.zero_grad()
        # 역전파를 통해 매개 변수의 loss에 대한 미분값을 계산한다.
        D_loss.backward()
        # 최적화 기법을 이용해 구분자의 매개 변수를 업데이트한다.
        D_optimizer.step()
        
        if leave_log:
            D_losses.append(D_loss.data)

        # train generator G

        ### 생성자 학습시키기
        
        # 생성자에 입력으로 줄 랜덤 벡터 z를 만든다.
        z = Variable(torch.randn((batch_size, 100)))
        
        if use_gpu:
            z = z.cuda()
        
        # 생성자로 가짜 이미지를 생성한다.
        fake_data = G(z)
        # 생성자가 만든 가짜 이미지를 구분자에 넣는다.
        D_result_from_fake = D(fake_data)
        # 생성자의 입장에서 구분자의 출력값이 1에서 멀수록 loss가 높아진다.
        G_loss = criterion(D_result_from_fake, target_real)
        
        # 생성자의 매개 변수의 미분값을 0으로 초기화한다.
        G.zero_grad()
        # 역전파를 통해 매개 변수의 loss에 대한 미분값을 계산한다.
        G_loss.backward()
        # 최적화 기법을 이용해 생성자의 매개 변수를 업데이트한다.
        G_optimizer.step()
        
        if leave_log:
            G_losses.append(G_loss.data)
    if leave_log:
        true_positive_rate = (D_result_from_real > 0.5).float().mean().data
        true_negative_rate = (D_result_from_fake < 0.5).float().mean().data
        base_message = ("Epoch: {epoch:<3d} D Loss: {d_loss:<8.6} G Loss: {g_loss:<8.6} "
                        "True Positive Rate: {tpr:<5.1%} True Negative Rate: {tnr:<5.1%}"
                       )
        message = base_message.format(
                    epoch=epoch,
                    d_loss=sum(D_losses)/len(D_losses),
                    g_loss=sum(G_losses)/len(G_losses),
                    tpr=true_positive_rate,
                    tnr=true_negative_rate
        )
        print(message)
    
    if leave_log:
        fake_data_fixed = G(z_fixed)
        image_path = result_dir + '/epoch{}.png'.format(epoch)
        square_plot(fake_data_fixed.view(25, 28, 28).cpu().data.numpy(), path=image_path)
        generated_images.append(image_path)
    
    if leave_log:
        train_hist['D_losses'].append(torch.mean(torch.FloatTensor(D_losses)))
        train_hist['G_losses'].append(torch.mean(torch.FloatTensor(G_losses)))

torch.save(G.state_dict(), "dcgan_generator.pkl")
torch.save(D.state_dict(), "dcgan_discriminator.pkl")
with open('dcgan_train_history.pkl', 'wb') as f:
    pickle.dump(train_hist, f)

generated_image_array = [imageio.imread(generated_image) for generated_image in generated_images]
imageio.mimsave(result_dir + '/DCGAN_generation.gif', generated_image_array, fps=5)
# Out:
# Epoch: 0   D Loss: 0.62582  G Loss: 1.83924  True Positive Rate: 95.0% True Negative Rate: 93.3%
# Epoch: 1   D Loss: 0.614077 G Loss: 1.90675  True Positive Rate: 56.7% True Negative Rate: 76.7%
# Epoch: 2   D Loss: 0.600338 G Loss: 2.00435  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 3   D Loss: 0.611626 G Loss: 2.02119  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 4   D Loss: 0.604551 G Loss: 2.06359  True Positive Rate: 76.7% True Negative Rate: 71.7%
# Epoch: 5   D Loss: 0.591834 G Loss: 2.12721  True Positive Rate: 88.3% True Negative Rate: 95.0%
# Epoch: 6   D Loss: 0.578171 G Loss: 2.17746  True Positive Rate: 93.3% True Negative Rate: 96.7%
# Epoch: 7   D Loss: 0.568053 G Loss: 2.23859  True Positive Rate: 85.0% True Negative Rate: 96.7%
# Epoch: 8   D Loss: 0.552544 G Loss: 2.26084  True Positive Rate: 88.3% True Negative Rate: 95.0%
# Epoch: 9   D Loss: 0.545028 G Loss: 2.32223  True Positive Rate: 98.3% True Negative Rate: 95.0%
# Epoch: 10  D Loss: 0.524794 G Loss: 2.38879  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 11  D Loss: 0.500662 G Loss: 2.44765  True Positive Rate: 78.3% True Negative Rate: 95.0%
# Epoch: 12  D Loss: 0.496163 G Loss: 2.50044  True Positive Rate: 100.0% True Negative Rate: 96.7%
# Epoch: 13  D Loss: 0.494674 G Loss: 2.52604  True Positive Rate: 93.3% True Negative Rate: 100.0%
# Epoch: 14  D Loss: 0.498706 G Loss: 2.52987  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 15  D Loss: 0.482795 G Loss: 2.58293  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 16  D Loss: 0.481754 G Loss: 2.62886  True Positive Rate: 95.0% True Negative Rate: 91.7%
# Epoch: 17  D Loss: 0.459918 G Loss: 2.6691   True Positive Rate: 93.3% True Negative Rate: 83.3%
# Epoch: 18  D Loss: 0.451865 G Loss: 2.71796  True Positive Rate: 100.0% True Negative Rate: 93.3%
# Epoch: 19  D Loss: 0.460197 G Loss: 2.73173  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 20  D Loss: 0.46174  G Loss: 2.7544   True Positive Rate: 83.3% True Negative Rate: 98.3%
# Epoch: 21  D Loss: 0.430388 G Loss: 2.7772   True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 22  D Loss: 0.439117 G Loss: 2.79439  True Positive Rate: 93.3% True Negative Rate: 88.3%
# Epoch: 23  D Loss: 0.438396 G Loss: 2.84623  True Positive Rate: 81.7% True Negative Rate: 93.3%
# Epoch: 24  D Loss: 0.437158 G Loss: 2.84494  True Positive Rate: 68.3% True Negative Rate: 63.3%
# Epoch: 25  D Loss: 0.43088  G Loss: 2.85053  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 26  D Loss: 0.428131 G Loss: 2.87793  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 27  D Loss: 0.434544 G Loss: 2.87502  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 28  D Loss: 0.41608  G Loss: 2.92937  True Positive Rate: 98.3% True Negative Rate: 95.0%
# Epoch: 29  D Loss: 0.41644  G Loss: 2.90822  True Positive Rate: 86.7% True Negative Rate: 93.3%
# Epoch: 30  D Loss: 0.420947 G Loss: 2.94278  True Positive Rate: 96.7% True Negative Rate: 96.7%
# Epoch: 31  D Loss: 0.418703 G Loss: 2.95627  True Positive Rate: 70.0% True Negative Rate: 93.3%
# Epoch: 32  D Loss: 0.407792 G Loss: 2.96166  True Positive Rate: 95.0% True Negative Rate: 100.0%
# Epoch: 33  D Loss: 0.414523 G Loss: 2.98514  True Positive Rate: 93.3% True Negative Rate: 96.7%
# Epoch: 34  D Loss: 0.411361 G Loss: 3.01242  True Positive Rate: 83.3% True Negative Rate: 75.0%
# Epoch: 35  D Loss: 0.41391  G Loss: 3.02306  True Positive Rate: 83.3% True Negative Rate: 96.7%
# Epoch: 36  D Loss: 0.401186 G Loss: 3.01793  True Positive Rate: 90.0% True Negative Rate: 98.3%
# Epoch: 37  D Loss: 0.396825 G Loss: 3.05652  True Positive Rate: 90.0% True Negative Rate: 98.3%
# Epoch: 38  D Loss: 0.41665  G Loss: 3.06222  True Positive Rate: 96.7% True Negative Rate: 100.0%
# Epoch: 39  D Loss: 0.394932 G Loss: 3.06226  True Positive Rate: 98.3% True Negative Rate: 95.0%
# Epoch: 40  D Loss: 0.400578 G Loss: 3.09414  True Positive Rate: 91.7% True Negative Rate: 93.3%
# Epoch: 41  D Loss: 0.391171 G Loss: 3.10139  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 42  D Loss: 0.399148 G Loss: 3.13018  True Positive Rate: 90.0% True Negative Rate: 98.3%
# Epoch: 43  D Loss: 0.385895 G Loss: 3.13334  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 44  D Loss: 0.375188 G Loss: 3.15962  True Positive Rate: 91.7% True Negative Rate: 96.7%
# Epoch: 45  D Loss: 0.387607 G Loss: 3.12184  True Positive Rate: 100.0% True Negative Rate: 83.3%
# Epoch: 46  D Loss: 0.379361 G Loss: 3.20513  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 47  D Loss: 0.386858 G Loss: 3.19016  True Positive Rate: 96.7% True Negative Rate: 96.7%
# Epoch: 48  D Loss: 0.375413 G Loss: 3.21278  True Positive Rate: 91.7% True Negative Rate: 95.0%
# Epoch: 49  D Loss: 0.367311 G Loss: 3.25019  True Positive Rate: 73.3% True Negative Rate: 86.7%
# Epoch: 50  D Loss: 0.370135 G Loss: 3.24474  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 51  D Loss: 0.371879 G Loss: 3.27225  True Positive Rate: 60.0% True Negative Rate: 95.0%
# Epoch: 52  D Loss: 0.366612 G Loss: 3.29525  True Positive Rate: 78.3% True Negative Rate: 85.0%
# Epoch: 53  D Loss: 0.356978 G Loss: 3.31352  True Positive Rate: 83.3% True Negative Rate: 98.3%
# Epoch: 54  D Loss: 0.360169 G Loss: 3.32792  True Positive Rate: 100.0% True Negative Rate: 93.3%
# Epoch: 55  D Loss: 0.360926 G Loss: 3.30443  True Positive Rate: 95.0% True Negative Rate: 96.7%
# Epoch: 56  D Loss: 0.361574 G Loss: 3.34645  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 57  D Loss: 0.357946 G Loss: 3.3176   True Positive Rate: 98.3% True Negative Rate: 96.7%
# Epoch: 58  D Loss: 0.357424 G Loss: 3.34796  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 59  D Loss: 0.346518 G Loss: 3.36168  True Positive Rate: 96.7% True Negative Rate: 91.7%
# Epoch: 60  D Loss: 0.351147 G Loss: 3.38329  True Positive Rate: 95.0% True Negative Rate: 95.0%
# Epoch: 61  D Loss: 0.352905 G Loss: 3.42037  True Positive Rate: 91.7% True Negative Rate: 91.7%
# Epoch: 62  D Loss: 0.349725 G Loss: 3.42525  True Positive Rate: 98.3% True Negative Rate: 83.3%
# Epoch: 63  D Loss: 0.351788 G Loss: 3.44957  True Positive Rate: 83.3% True Negative Rate: 71.7%
# Epoch: 64  D Loss: 0.331997 G Loss: 3.43462  True Positive Rate: 96.7% True Negative Rate: 100.0%
# Epoch: 65  D Loss: 0.340993 G Loss: 3.43905  True Positive Rate: 83.3% True Negative Rate: 71.7%
# Epoch: 66  D Loss: 0.345676 G Loss: 3.44595  True Positive Rate: 96.7% True Negative Rate: 96.7%
# Epoch: 67  D Loss: 0.323723 G Loss: 3.48477  True Positive Rate: 53.3% True Negative Rate: 71.7%
# Epoch: 68  D Loss: 0.32981  G Loss: 3.49164  True Positive Rate: 96.7% True Negative Rate: 100.0%
# Epoch: 69  D Loss: 0.327211 G Loss: 3.51473  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 70  D Loss: 0.342835 G Loss: 3.52092  True Positive Rate: 75.0% True Negative Rate: 96.7%
# Epoch: 71  D Loss: 0.322214 G Loss: 3.52489  True Positive Rate: 90.0% True Negative Rate: 91.7%
# Epoch: 72  D Loss: 0.323454 G Loss: 3.56663  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 73  D Loss: 0.326317 G Loss: 3.54292  True Positive Rate: 100.0% True Negative Rate: 93.3%
# Epoch: 74  D Loss: 0.32886  G Loss: 3.57998  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 75  D Loss: 0.333045 G Loss: 3.57993  True Positive Rate: 95.0% True Negative Rate: 98.3%
# Epoch: 76  D Loss: 0.307317 G Loss: 3.59472  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 77  D Loss: 0.32262  G Loss: 3.59382  True Positive Rate: 86.7% True Negative Rate: 100.0%
# Epoch: 78  D Loss: 0.319169 G Loss: 3.63295  True Positive Rate: 98.3% True Negative Rate: 95.0%
# Epoch: 79  D Loss: 0.318208 G Loss: 3.64036  True Positive Rate: 98.3% True Negative Rate: 95.0%
# Epoch: 80  D Loss: 0.314679 G Loss: 3.63068  True Positive Rate: 45.0% True Negative Rate: 88.3%
# Epoch: 81  D Loss: 0.315933 G Loss: 3.65345  True Positive Rate: 73.3% True Negative Rate: 66.7%
# Epoch: 82  D Loss: 0.332913 G Loss: 3.69308  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 83  D Loss: 0.301294 G Loss: 3.65757  True Positive Rate: 100.0% True Negative Rate: 88.3%
# Epoch: 84  D Loss: 0.30229  G Loss: 3.67868  True Positive Rate: 86.7% True Negative Rate: 91.7%
# Epoch: 85  D Loss: 0.299436 G Loss: 3.7138   True Positive Rate: 100.0% True Negative Rate: 96.7%
# Epoch: 86  D Loss: 0.316379 G Loss: 3.73151  True Positive Rate: 100.0% True Negative Rate: 98.3%
# Epoch: 87  D Loss: 0.316065 G Loss: 3.74346  True Positive Rate: 96.7% True Negative Rate: 98.3%
# Epoch: 88  D Loss: 0.295146 G Loss: 3.66381  True Positive Rate: 80.0% True Negative Rate: 100.0%
# Epoch: 89  D Loss: 0.314578 G Loss: 3.75639  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 90  D Loss: 0.306514 G Loss: 3.76938  True Positive Rate: 96.7% True Negative Rate: 100.0%
# Epoch: 91  D Loss: 0.292188 G Loss: 3.76346  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 92  D Loss: 0.302106 G Loss: 3.77825  True Positive Rate: 100.0% True Negative Rate: 100.0%
# Epoch: 93  D Loss: 0.313521 G Loss: 3.76799  True Positive Rate: 100.0% True Negative Rate: 90.0%
# Epoch: 94  D Loss: 0.286413 G Loss: 3.82515  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 95  D Loss: 0.296921 G Loss: 3.78845  True Positive Rate: 100.0% True Negative Rate: 78.3%
# Epoch: 96  D Loss: 0.292681 G Loss: 3.76871  True Positive Rate: 73.3% True Negative Rate: 86.7%
# Epoch: 97  D Loss: 0.28311  G Loss: 3.85003  True Positive Rate: 96.7% True Negative Rate: 98.3%
# Epoch: 98  D Loss: 0.303859 G Loss: 3.80178  True Positive Rate: 98.3% True Negative Rate: 100.0%
# Epoch: 99  D Loss: 0.282271 G Loss: 3.80029  True Positive Rate: 100.0% True Negative Rate: 88.3%
