# %% [markdown]
# <a href="https://colab.research.google.com/github/bangse94/StudyDL/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import math
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''

# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2
'''

class VGG13(nn.Module) :
    def __init__(self) :
        super(VGG13, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),    # 64 * 32 * 32
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 4096),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(4096, 10),                     # 1 * num_class
                )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()
        
    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output


'''
Step 3
'''
model = VGG13().to(device)
loss_function = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=128, shuffle=True)

import time
start = time.time()
for epoch in range(200) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))

time.strftime("Training Time : %H:%M:%S", time.gmtime(end-start))
'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar_10data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./cifar_10data/cifar-10-python.tar.gz to ./cifar_10data/
# 0th epoch starting.
# Epoch [1] Loss: 2.3021
# 1th epoch starting.
# Epoch [2] Loss: 2.3034
# 2th epoch starting.
# Epoch [3] Loss: 2.3064
# 3th epoch starting.
# Epoch [4] Loss: 2.3001
# 4th epoch starting.
# Epoch [5] Loss: 2.3046
# 5th epoch starting.
# Epoch [6] Loss: 2.3049
# 6th epoch starting.
# Epoch [7] Loss: 2.3047
# 7th epoch starting.
# Epoch [8] Loss: 2.3007
# 8th epoch starting.
# Epoch [9] Loss: 2.3017
# 9th epoch starting.
# Epoch [10] Loss: 2.3036
# 10th epoch starting.
# Epoch [11] Loss: 2.3053
# 11th epoch starting.
# Epoch [12] Loss: 2.3005
# 12th epoch starting.
# Epoch [13] Loss: 2.3024
# 13th epoch starting.
# Epoch [14] Loss: 2.3014
# 14th epoch starting.
# Epoch [15] Loss: 2.2975
# 15th epoch starting.
# Epoch [16] Loss: 2.3062
# 16th epoch starting.
# Epoch [17] Loss: 2.3036
# 17th epoch starting.
# Epoch [18] Loss: 2.2977
# 18th epoch starting.
# Epoch [19] Loss: 2.3113
# 19th epoch starting.
# Epoch [20] Loss: 2.3025
# 20th epoch starting.
# Epoch [21] Loss: 2.3030
# 21th epoch starting.
# Epoch [22] Loss: 2.3051
# 22th epoch starting.
# Epoch [23] Loss: 2.3095
# 23th epoch starting.
# Epoch [24] Loss: 2.3052
# 24th epoch starting.
# Epoch [25] Loss: 2.2930
# 25th epoch starting.
# Epoch [26] Loss: 2.2928
# 26th epoch starting.
# Epoch [27] Loss: 2.3026
# 27th epoch starting.
# Epoch [28] Loss: 2.3028
# 28th epoch starting.
# Epoch [29] Loss: 2.3070
# 29th epoch starting.
# Epoch [30] Loss: 2.3055
# 30th epoch starting.
# Epoch [31] Loss: 2.3036
# 31th epoch starting.
# Epoch [32] Loss: 2.3072
# 32th epoch starting.
# Epoch [33] Loss: 2.3015
# 33th epoch starting.
# Epoch [34] Loss: 2.3010
# 34th epoch starting.
# Epoch [35] Loss: 2.2997
# 35th epoch starting.
# Epoch [36] Loss: 2.3030
# 36th epoch starting.
# Epoch [37] Loss: 2.3053
# 37th epoch starting.
# Epoch [38] Loss: 2.3060
# 38th epoch starting.
# Epoch [39] Loss: 2.3066
# 39th epoch starting.
# Epoch [40] Loss: 2.2998
# 40th epoch starting.
# Epoch [41] Loss: 2.3036
# 41th epoch starting.
# Epoch [42] Loss: 2.3051
# 42th epoch starting.
# Epoch [43] Loss: 2.2989
# 43th epoch starting.
# Epoch [44] Loss: 2.3110
# 44th epoch starting.
# Epoch [45] Loss: 2.3012
# 45th epoch starting.
# Epoch [46] Loss: 2.2959
# 46th epoch starting.
# Epoch [47] Loss: 2.3009
# 47th epoch starting.
# Epoch [48] Loss: 2.3050
# 48th epoch starting.
# Epoch [49] Loss: 2.3154
# 49th epoch starting.
# Epoch [50] Loss: 2.3109
# 50th epoch starting.
# Epoch [51] Loss: 2.2963
# 51th epoch starting.
# Epoch [52] Loss: 2.3053
# 52th epoch starting.
# Epoch [53] Loss: 2.3071
# 53th epoch starting.
# Epoch [54] Loss: 2.2996
# 54th epoch starting.
# Epoch [55] Loss: 2.3019
# 55th epoch starting.
# Epoch [56] Loss: 2.3078
# 56th epoch starting.
# Epoch [57] Loss: 2.3015
# 57th epoch starting.
# Epoch [58] Loss: 2.3028
# 58th epoch starting.
# Epoch [59] Loss: 2.2951
# 59th epoch starting.
# Epoch [60] Loss: 2.3003
# 60th epoch starting.
# Epoch [61] Loss: 2.3044
# 61th epoch starting.
# Epoch [62] Loss: 2.3063
# 62th epoch starting.
# Epoch [63] Loss: 2.3094
# 63th epoch starting.
# Epoch [64] Loss: 2.2965
# 64th epoch starting.
# Epoch [65] Loss: 2.3062
# 65th epoch starting.
# Epoch [66] Loss: 2.3063
# 66th epoch starting.
# Epoch [67] Loss: 2.3043
# 67th epoch starting.
# Epoch [68] Loss: 2.3042
# 68th epoch starting.
# Epoch [69] Loss: 2.3083
# 69th epoch starting.
# Epoch [70] Loss: 2.3047
# 70th epoch starting.
# Epoch [71] Loss: 2.3035
# 71th epoch starting.
# Epoch [72] Loss: 2.3017
# 72th epoch starting.
# Epoch [73] Loss: 2.3034
# 73th epoch starting.
# Epoch [74] Loss: 2.2992
# 74th epoch starting.
# Epoch [75] Loss: 2.3067
# 75th epoch starting.
# Epoch [76] Loss: 2.3013
# 76th epoch starting.
# Epoch [77] Loss: 2.3059
# 77th epoch starting.
# Epoch [78] Loss: 2.3039
# 78th epoch starting.
# Epoch [79] Loss: 2.3006
# 79th epoch starting.
# Epoch [80] Loss: 2.3028
# 80th epoch starting.
# Epoch [81] Loss: 2.3003
# 81th epoch starting.
# Epoch [82] Loss: 2.3044
# 82th epoch starting.
# Epoch [83] Loss: 2.3059
# 83th epoch starting.
# Epoch [84] Loss: 2.3043
# 84th epoch starting.
# Epoch [85] Loss: 2.3040
# 85th epoch starting.
# Epoch [86] Loss: 2.2979
# 86th epoch starting.
# Epoch [87] Loss: 2.3071
# 87th epoch starting.
# Epoch [88] Loss: 2.2989
# 88th epoch starting.
# Epoch [89] Loss: 2.3010
# 89th epoch starting.
# Epoch [90] Loss: 2.3069
# 90th epoch starting.
# Epoch [91] Loss: 2.3050
# 91th epoch starting.
# Epoch [92] Loss: 2.3006
# 92th epoch starting.
# Epoch [93] Loss: 2.3022
# 93th epoch starting.
# Epoch [94] Loss: 2.2949
# 94th epoch starting.
# Epoch [95] Loss: 2.3031
# 95th epoch starting.
# Epoch [96] Loss: 2.3019
# 96th epoch starting.
# Epoch [97] Loss: 2.3053
# 97th epoch starting.
# Epoch [98] Loss: 2.2982
# 98th epoch starting.
# Epoch [99] Loss: 2.3042
# 99th epoch starting.
# Epoch [100] Loss: 2.3040
# 100th epoch starting.
# Epoch [101] Loss: 2.3071
# 101th epoch starting.
# Epoch [102] Loss: 2.3027
# 102th epoch starting.
# Epoch [103] Loss: 2.3024
# 103th epoch starting.
# Epoch [104] Loss: 2.3074
# 104th epoch starting.
# Epoch [105] Loss: 2.3066
# 105th epoch starting.
# Epoch [106] Loss: 2.3081
# 106th epoch starting.
# Epoch [107] Loss: 2.3049
# 107th epoch starting.
# Epoch [108] Loss: 2.3091
# 108th epoch starting.
# Epoch [109] Loss: 2.2997
# 109th epoch starting.
# Epoch [110] Loss: 2.3020
# 110th epoch starting.
# Epoch [111] Loss: 2.3074
# 111th epoch starting.
# Epoch [112] Loss: 2.3076
# 112th epoch starting.
# Epoch [113] Loss: 2.3082
# 113th epoch starting.
# Epoch [114] Loss: 2.3118
# 114th epoch starting.
# Epoch [115] Loss: 2.2980
# 115th epoch starting.
# Epoch [116] Loss: 2.3048
# 116th epoch starting.
# Epoch [117] Loss: 2.3048
# 117th epoch starting.
# Epoch [118] Loss: 2.3026
# 118th epoch starting.
# Epoch [119] Loss: 2.2991
# 119th epoch starting.
# Epoch [120] Loss: 2.2979
# 120th epoch starting.
# Epoch [121] Loss: 2.2975
# 121th epoch starting.
# Epoch [122] Loss: 2.3002
# 122th epoch starting.
# Epoch [123] Loss: 2.3049
# 123th epoch starting.
# Epoch [124] Loss: 2.3110
# 124th epoch starting.
# Epoch [125] Loss: 2.3075
# 125th epoch starting.
# Epoch [126] Loss: 2.2985
# 126th epoch starting.
# Epoch [127] Loss: 2.3011
# 127th epoch starting.
# Epoch [128] Loss: 2.3025
# 128th epoch starting.
# Epoch [129] Loss: 2.3081
# 129th epoch starting.
# Epoch [130] Loss: 2.3093
# 130th epoch starting.
# Epoch [131] Loss: 2.3094
# 131th epoch starting.
# Epoch [132] Loss: 2.3040
# 132th epoch starting.
# Epoch [133] Loss: 2.3026
# 133th epoch starting.
# Epoch [134] Loss: 2.3033
# 134th epoch starting.
# Epoch [135] Loss: 2.3013
# 135th epoch starting.
# Epoch [136] Loss: 2.3017
# 136th epoch starting.
# Epoch [137] Loss: 2.2998
# 137th epoch starting.
# Epoch [138] Loss: 2.3021
# 138th epoch starting.
# Epoch [139] Loss: 2.3123
# 139th epoch starting.
# Epoch [140] Loss: 2.2991
# 140th epoch starting.
# Epoch [141] Loss: 2.3019
# 141th epoch starting.
# Epoch [142] Loss: 2.3042
# 142th epoch starting.
# Epoch [143] Loss: 2.3038
# 143th epoch starting.
# Epoch [144] Loss: 2.3002
# 144th epoch starting.
# Epoch [145] Loss: 2.3028
# 145th epoch starting.
# Epoch [146] Loss: 2.2984
# 146th epoch starting.
# Epoch [147] Loss: 2.3073
# 147th epoch starting.
# Epoch [148] Loss: 2.2974
# 148th epoch starting.
# Epoch [149] Loss: 2.3017
# 149th epoch starting.
# Epoch [150] Loss: 2.3084
# 150th epoch starting.
# Epoch [151] Loss: 2.2998
# 151th epoch starting.
# Epoch [152] Loss: 2.3069
# 152th epoch starting.
# Epoch [153] Loss: 2.2997
# 153th epoch starting.
# Epoch [154] Loss: 2.3060
# 154th epoch starting.
# Epoch [155] Loss: 2.2995
# 155th epoch starting.
# Epoch [156] Loss: 2.3067
# 156th epoch starting.
# Epoch [157] Loss: 2.2958
# 157th epoch starting.
# Epoch [158] Loss: 2.3051
# 158th epoch starting.
# Epoch [159] Loss: 2.2965
# 159th epoch starting.
# Epoch [160] Loss: 2.3170
# 160th epoch starting.
# Epoch [161] Loss: 2.3041
# 161th epoch starting.
# Epoch [162] Loss: 2.3082
# 162th epoch starting.
# Epoch [163] Loss: 2.2978
# 163th epoch starting.
# Epoch [164] Loss: 2.2994
# 164th epoch starting.
# Epoch [165] Loss: 2.3050
# 165th epoch starting.
# Epoch [166] Loss: 2.3046
# 166th epoch starting.
# Epoch [167] Loss: 2.3034
# 167th epoch starting.
# Epoch [168] Loss: 2.3023
# 168th epoch starting.
# Epoch [169] Loss: 2.3017
# 169th epoch starting.
# Epoch [170] Loss: 2.3100
# 170th epoch starting.
# Epoch [171] Loss: 2.3070
# 171th epoch starting.
# Epoch [172] Loss: 2.2995
# 172th epoch starting.
# Epoch [173] Loss: 2.3016
# 173th epoch starting.
# Epoch [174] Loss: 2.3035
# 174th epoch starting.
# Epoch [175] Loss: 2.3068
# 175th epoch starting.
# Epoch [176] Loss: 2.3089
# 176th epoch starting.
# Epoch [177] Loss: 2.3036
# 177th epoch starting.
# Epoch [178] Loss: 2.3043
# 178th epoch starting.
# Epoch [179] Loss: 2.3051
# 179th epoch starting.
# Epoch [180] Loss: 2.2989
# 180th epoch starting.
# Epoch [181] Loss: 2.3057
# 181th epoch starting.
# Epoch [182] Loss: 2.3131
# 182th epoch starting.
# Epoch [183] Loss: 2.3010
# 183th epoch starting.
# Epoch [184] Loss: 2.3048
# 184th epoch starting.
# Epoch [185] Loss: 2.3043
# 185th epoch starting.
# Epoch [186] Loss: 2.3040
# 186th epoch starting.
# Epoch [187] Loss: 2.3069
# 187th epoch starting.
# Epoch [188] Loss: 2.3002
# 188th epoch starting.
# Epoch [189] Loss: 2.3068
# 189th epoch starting.
# Epoch [190] Loss: 2.3117
# 190th epoch starting.
# Epoch [191] Loss: 2.3041
# 191th epoch starting.
# Epoch [192] Loss: 2.3081
# 192th epoch starting.
# Epoch [193] Loss: 2.3026
# 193th epoch starting.
# Epoch [194] Loss: 2.3038
# 194th epoch starting.
# Epoch [195] Loss: 2.3017
# 195th epoch starting.
# Epoch [196] Loss: 2.2971
# 196th epoch starting.
# Epoch [197] Loss: 2.3039
# 197th epoch starting.
# Epoch [198] Loss: 2.3006
# 198th epoch starting.
# Epoch [199] Loss: 2.3033
# 199th epoch starting.
# Epoch [200] Loss: 2.3054
# Time ellapsed in training is: 5005.412848472595
# [Test set] Average loss: 0.0230, Accuracy: 1000/10000 (10.00%)

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)  # 64 + 128 + 32 + 32 = 256
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        # N x 3 x 32 x 32
        x = self.conv1(x)
        # N x 64 x 32 x 32
        x = self.conv2(x)
        # N x 64 x 32 x 32
        x = self.conv3(x)
        # N x 192 x 28 x 28

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7
        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = torch.flatten(x, 1)
        # N x 1024
        x = self.dropout(x)
        x = self.fc(x)
        # N x 10 (num_classes)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))
time.strftime("Training Time : %H:%M:%S", time.gmtime(end-start))

'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 2.2240
# 1th epoch starting.
# Epoch [2] Loss: 1.9955
# 2th epoch starting.
# Epoch [3] Loss: 1.9662
# 3th epoch starting.
# Epoch [4] Loss: 1.7940
# 4th epoch starting.
# Epoch [5] Loss: 1.6683
# 5th epoch starting.
# Epoch [6] Loss: 1.6405
# 6th epoch starting.
# Epoch [7] Loss: 1.7883
# 7th epoch starting.
# Epoch [8] Loss: 1.5692
# 8th epoch starting.
# Epoch [9] Loss: 1.3301
# 9th epoch starting.
# Epoch [10] Loss: 1.4444
# 10th epoch starting.
# Epoch [11] Loss: 1.3193
# 11th epoch starting.
# Epoch [12] Loss: 1.3669
# 12th epoch starting.
# Epoch [13] Loss: 1.0689
# 13th epoch starting.
# Epoch [14] Loss: 1.4506
# 14th epoch starting.
# Epoch [15] Loss: 1.2475
# 15th epoch starting.
# Epoch [16] Loss: 1.3459
# 16th epoch starting.
# Epoch [17] Loss: 1.2361
# 17th epoch starting.
# Epoch [18] Loss: 1.0473
# 18th epoch starting.
# Epoch [19] Loss: 1.0105
# 19th epoch starting.
# Epoch [20] Loss: 1.3687
# 20th epoch starting.
# Epoch [21] Loss: 1.0753
# 21th epoch starting.
# Epoch [22] Loss: 0.8838
# 22th epoch starting.
# Epoch [23] Loss: 0.7367
# 23th epoch starting.
# Epoch [24] Loss: 0.9654
# 24th epoch starting.
# Epoch [25] Loss: 0.8128
# 25th epoch starting.
# Epoch [26] Loss: 0.7174
# 26th epoch starting.
# Epoch [27] Loss: 0.6526
# 27th epoch starting.
# Epoch [28] Loss: 0.7903
# 28th epoch starting.
# Epoch [29] Loss: 0.7072
# 29th epoch starting.
# Epoch [30] Loss: 0.7350
# 30th epoch starting.
# Epoch [31] Loss: 0.6519
# 31th epoch starting.
# Epoch [32] Loss: 0.6540
# 32th epoch starting.
# Epoch [33] Loss: 0.5369
# 33th epoch starting.
# Epoch [34] Loss: 0.5043
# 34th epoch starting.
# Epoch [35] Loss: 0.4900
# 35th epoch starting.
# Epoch [36] Loss: 0.9649
# 36th epoch starting.
# Epoch [37] Loss: 0.8534
# 37th epoch starting.
# Epoch [38] Loss: 0.5152
# 38th epoch starting.
# Epoch [39] Loss: 0.7276
# 39th epoch starting.
# Epoch [40] Loss: 0.6538
# 40th epoch starting.
# Epoch [41] Loss: 0.6474
# 41th epoch starting.
# Epoch [42] Loss: 0.4611
# 42th epoch starting.
# Epoch [43] Loss: 0.4159
# 43th epoch starting.
# Epoch [44] Loss: 0.5884
# 44th epoch starting.
# Epoch [45] Loss: 0.3857
# 45th epoch starting.
# Epoch [46] Loss: 0.9631
# 46th epoch starting.
# Epoch [47] Loss: 0.5255
# 47th epoch starting.
# Epoch [48] Loss: 0.5196
# 48th epoch starting.
# Epoch [49] Loss: 0.5488
# 49th epoch starting.
# Epoch [50] Loss: 0.5325
# 50th epoch starting.
# Epoch [51] Loss: 0.4199
# 51th epoch starting.
# Epoch [52] Loss: 0.5210
# 52th epoch starting.
# Epoch [53] Loss: 0.4294
# 53th epoch starting.
# Epoch [54] Loss: 0.4712
# 54th epoch starting.
# Epoch [55] Loss: 0.3426
# 55th epoch starting.
# Epoch [56] Loss: 0.7133
# 56th epoch starting.
# Epoch [57] Loss: 0.3849
# 57th epoch starting.
# Epoch [58] Loss: 0.2998
# 58th epoch starting.
# Epoch [59] Loss: 0.3051
# 59th epoch starting.
# Epoch [60] Loss: 0.3813
# 60th epoch starting.
# Epoch [61] Loss: 0.3512
# 61th epoch starting.
# Epoch [62] Loss: 0.4771
# 62th epoch starting.
# Epoch [63] Loss: 0.2183
# 63th epoch starting.
# Epoch [64] Loss: 0.4364
# 64th epoch starting.
# Epoch [65] Loss: 0.1432
# 65th epoch starting.
# Epoch [66] Loss: 0.3088
# 66th epoch starting.
# Epoch [67] Loss: 0.2314
# 67th epoch starting.
# Epoch [68] Loss: 0.2974
# 68th epoch starting.
# Epoch [69] Loss: 0.3208
# 69th epoch starting.
# Epoch [70] Loss: 0.2658
# 70th epoch starting.
# Epoch [71] Loss: 0.3390
# 71th epoch starting.
# Epoch [72] Loss: 0.2260
# 72th epoch starting.
# Epoch [73] Loss: 0.2070
# 73th epoch starting.
# Epoch [74] Loss: 0.5231
# 74th epoch starting.
# Epoch [75] Loss: 0.3252
# 75th epoch starting.

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool3(x)

        x = self.inception4a(x)
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        x = self.inception4e(x)
        x = self.maxpool4(x)

        x = self.inception5a(x)
        x = self.inception5b(x)
        x = self.avgpool(x)
        
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.BatchNorm2d(out_channels),   #Batch norm here
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))
time.strftime("Training Time : %H:%M:%S", time.gmtime(end-start))

'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms
import torch.nn.functional as F

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])


'''
Step 3
'''
model = ResNet18().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.03, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))
time.strftime("Training Time : %H:%M:%S", time.gmtime(end-start))

'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
