# %% [markdown]
# <a href="https://colab.research.google.com/github/bangse94/StudyDL/blob/main/ML_Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import math
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''

# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2
'''

class VGG13(nn.Module) :
    def __init__(self) :
        super(VGG13, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),    # 64 * 32 * 32
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 4096),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(4096, 10),                     # 1 * num_class
                )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()
        
    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output


'''
Step 3
'''
model = VGG13().to(device)
loss_function = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=128, shuffle=True)

import time
start = time.time()
for epoch in range(200) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 2.2856
# 1th epoch starting.
# Epoch [2] Loss: 1.9364
# 2th epoch starting.
# Epoch [3] Loss: 1.9189
# 3th epoch starting.
# Epoch [4] Loss: 1.6568
# 4th epoch starting.
# Epoch [5] Loss: 1.2673
# 5th epoch starting.
# Epoch [6] Loss: 1.2830
# 6th epoch starting.
# Epoch [7] Loss: 1.1691
# 7th epoch starting.
# Epoch [8] Loss: 0.9255
# 8th epoch starting.
# Epoch [9] Loss: 0.8387
# 9th epoch starting.
# Epoch [10] Loss: 0.8149
# 10th epoch starting.
# Epoch [11] Loss: 0.9798
# 11th epoch starting.
# Epoch [12] Loss: 0.3870
# 12th epoch starting.
# Epoch [13] Loss: 0.7704
# 13th epoch starting.
# Epoch [14] Loss: 0.6610
# 14th epoch starting.
# Epoch [15] Loss: 0.5486
# 15th epoch starting.
# Epoch [16] Loss: 0.7977
# 16th epoch starting.
# Epoch [17] Loss: 0.7029
# 17th epoch starting.
# Epoch [18] Loss: 0.6051
# 18th epoch starting.
# Epoch [19] Loss: 0.6508
# 19th epoch starting.
# Epoch [20] Loss: 0.3977
# 20th epoch starting.
# Epoch [21] Loss: 0.4612
# 21th epoch starting.
# Epoch [22] Loss: 0.8147
# 22th epoch starting.
# Epoch [23] Loss: 0.5060
# 23th epoch starting.
# Epoch [24] Loss: 0.4078
# 24th epoch starting.
# Epoch [25] Loss: 0.3063
# 25th epoch starting.
# Epoch [26] Loss: 0.5025
# 26th epoch starting.
# Epoch [27] Loss: 0.7896
# 27th epoch starting.
# Epoch [28] Loss: 0.4454
# 28th epoch starting.
# Epoch [29] Loss: 0.4285
# 29th epoch starting.
# Epoch [30] Loss: 0.6072
# 30th epoch starting.
# Epoch [31] Loss: 0.5015
# 31th epoch starting.
# Epoch [32] Loss: 0.4337
# 32th epoch starting.
# Epoch [33] Loss: 0.3873
# 33th epoch starting.
# Epoch [34] Loss: 0.5360
# 34th epoch starting.
# Epoch [35] Loss: 0.5534
# 35th epoch starting.
# Epoch [36] Loss: 0.4761
# 36th epoch starting.
# Epoch [37] Loss: 0.4513
# 37th epoch starting.
# Epoch [38] Loss: 0.2562
# 38th epoch starting.
# Epoch [39] Loss: 0.4928
# 39th epoch starting.
# Epoch [40] Loss: 0.3145
# 40th epoch starting.
# Epoch [41] Loss: 0.4842
# 41th epoch starting.
# Epoch [42] Loss: 0.2636
# 42th epoch starting.
# Epoch [43] Loss: 0.3365
# 43th epoch starting.
# Epoch [44] Loss: 0.3906
# 44th epoch starting.
# Epoch [45] Loss: 0.3995
# 45th epoch starting.
# Epoch [46] Loss: 0.4174
# 46th epoch starting.
# Epoch [47] Loss: 0.2266
# 47th epoch starting.
# Epoch [48] Loss: 0.3430
# 48th epoch starting.
# Epoch [49] Loss: 0.3475
# 49th epoch starting.
# Epoch [50] Loss: 0.2640
# 50th epoch starting.
# Epoch [51] Loss: 0.3791
# 51th epoch starting.
# Epoch [52] Loss: 0.2225
# 52th epoch starting.
# Epoch [53] Loss: 0.2478
# 53th epoch starting.
# Epoch [54] Loss: 0.2886
# 54th epoch starting.
# Epoch [55] Loss: 0.3133
# 55th epoch starting.
# Epoch [56] Loss: 0.4027
# 56th epoch starting.
# Epoch [57] Loss: 0.3059
# 57th epoch starting.
# Epoch [58] Loss: 0.3344
# 58th epoch starting.
# Epoch [59] Loss: 0.3039
# 59th epoch starting.
# Epoch [60] Loss: 0.4497
# 60th epoch starting.
# Epoch [61] Loss: 0.3325
# 61th epoch starting.
# Epoch [62] Loss: 0.3887
# 62th epoch starting.
# Epoch [63] Loss: 0.2596
# 63th epoch starting.
# Epoch [64] Loss: 0.3848
# 64th epoch starting.
# Epoch [65] Loss: 0.3412
# 65th epoch starting.
# Epoch [66] Loss: 0.3296
# 66th epoch starting.
# Epoch [67] Loss: 0.4759
# 67th epoch starting.
# Epoch [68] Loss: 0.3243
# 68th epoch starting.
# Epoch [69] Loss: 0.3238
# 69th epoch starting.
# Epoch [70] Loss: 0.2593
# 70th epoch starting.
# Epoch [71] Loss: 0.3814
# 71th epoch starting.
# Epoch [72] Loss: 0.3704
# 72th epoch starting.
# Epoch [73] Loss: 0.4931
# 73th epoch starting.
# Epoch [74] Loss: 0.2105
# 74th epoch starting.
# Epoch [75] Loss: 0.2404
# 75th epoch starting.
# Epoch [76] Loss: 0.3278
# 76th epoch starting.
# Epoch [77] Loss: 0.2472
# 77th epoch starting.
# Epoch [78] Loss: 0.3811
# 78th epoch starting.
# Epoch [79] Loss: 0.3398
# 79th epoch starting.
# Epoch [80] Loss: 0.2376
# 80th epoch starting.
# Epoch [81] Loss: 0.2817
# 81th epoch starting.
# Epoch [82] Loss: 0.1724
# 82th epoch starting.
# Epoch [83] Loss: 0.3288
# 83th epoch starting.
# Epoch [84] Loss: 0.2671
# 84th epoch starting.
# Epoch [85] Loss: 0.2993
# 85th epoch starting.
# Epoch [86] Loss: 0.3676
# 86th epoch starting.
# Epoch [87] Loss: 0.2055
# 87th epoch starting.
# Epoch [88] Loss: 0.1709
# 88th epoch starting.
# Epoch [89] Loss: 0.3668
# 89th epoch starting.
# Epoch [90] Loss: 0.3144
# 90th epoch starting.
# Epoch [91] Loss: 0.1357
# 91th epoch starting.
# Epoch [92] Loss: 0.3034
# 92th epoch starting.
# Epoch [93] Loss: 0.1319
# 93th epoch starting.
# Epoch [94] Loss: 0.4538
# 94th epoch starting.
# Epoch [95] Loss: 0.3354
# 95th epoch starting.
# Epoch [96] Loss: 0.2403
# 96th epoch starting.
# Epoch [97] Loss: 0.1694
# 97th epoch starting.
# Epoch [98] Loss: 0.3338
# 98th epoch starting.
# Epoch [99] Loss: 0.3096
# 99th epoch starting.
# Epoch [100] Loss: 0.3016
# 100th epoch starting.
# Epoch [101] Loss: 0.2649
# 101th epoch starting.
# Epoch [102] Loss: 0.2648
# 102th epoch starting.
# Epoch [103] Loss: 0.2340
# 103th epoch starting.
# Epoch [104] Loss: 0.1854
# 104th epoch starting.
# Epoch [105] Loss: 0.3603
# 105th epoch starting.
# Epoch [106] Loss: 0.2444
# 106th epoch starting.
# Epoch [107] Loss: 0.4090
# 107th epoch starting.
# Epoch [108] Loss: 0.3354
# 108th epoch starting.
# Epoch [109] Loss: 0.2884
# 109th epoch starting.
# Epoch [110] Loss: 0.1904
# 110th epoch starting.
# Epoch [111] Loss: 0.3218
# 111th epoch starting.
# Epoch [112] Loss: 0.3559
# 112th epoch starting.
# Epoch [113] Loss: 0.2557
# 113th epoch starting.
# Epoch [114] Loss: 0.2384
# 114th epoch starting.
# Epoch [115] Loss: 0.3549
# 115th epoch starting.
# Epoch [116] Loss: 0.2676
# 116th epoch starting.
# Epoch [117] Loss: 0.1173
# 117th epoch starting.
# Epoch [118] Loss: 0.2950
# 118th epoch starting.
# Epoch [119] Loss: 0.3095
# 119th epoch starting.
# Epoch [120] Loss: 0.3066
# 120th epoch starting.
# Epoch [121] Loss: 0.2971
# 121th epoch starting.
# Epoch [122] Loss: 0.2825
# 122th epoch starting.
# Epoch [123] Loss: 0.3629
# 123th epoch starting.
# Epoch [124] Loss: 0.2293
# 124th epoch starting.
# Epoch [125] Loss: 0.2398
# 125th epoch starting.
# Epoch [126] Loss: 0.2896
# 126th epoch starting.
# Epoch [127] Loss: 0.3327
# 127th epoch starting.
# Epoch [128] Loss: 0.3474
# 128th epoch starting.
# Epoch [129] Loss: 0.0762
# 129th epoch starting.
# Epoch [130] Loss: 0.2360
# 130th epoch starting.
# Epoch [131] Loss: 0.1567
# 131th epoch starting.
# Epoch [132] Loss: 0.4153
# 132th epoch starting.
# Epoch [133] Loss: 0.2670
# 133th epoch starting.
# Epoch [134] Loss: 0.2334
# 134th epoch starting.
# Epoch [135] Loss: 0.3668
# 135th epoch starting.
# Epoch [136] Loss: 0.2543
# 136th epoch starting.
# Epoch [137] Loss: 0.1908
# 137th epoch starting.
# Epoch [138] Loss: 0.2508
# 138th epoch starting.
# Epoch [139] Loss: 0.3105
# 139th epoch starting.
# Epoch [140] Loss: 0.4029
# 140th epoch starting.
# Epoch [141] Loss: 0.3149
# 141th epoch starting.
# Epoch [142] Loss: 0.3381
# 142th epoch starting.
# Epoch [143] Loss: 0.2779
# 143th epoch starting.
# Epoch [144] Loss: 0.2117
# 144th epoch starting.
# Epoch [145] Loss: 0.3603
# 145th epoch starting.
# Epoch [146] Loss: 0.2026
# 146th epoch starting.
# Epoch [147] Loss: 0.2001
# 147th epoch starting.
# Epoch [148] Loss: 0.1516
# 148th epoch starting.
# Epoch [149] Loss: 0.1982
# 149th epoch starting.
# Epoch [150] Loss: 0.2696
# 150th epoch starting.
# Epoch [151] Loss: 0.2178
# 151th epoch starting.
# Epoch [152] Loss: 0.1842
# 152th epoch starting.
# Epoch [153] Loss: 0.3122
# 153th epoch starting.
# Epoch [154] Loss: 0.3146
# 154th epoch starting.
# Epoch [155] Loss: 0.2470
# 155th epoch starting.
# Epoch [156] Loss: 0.3197
# 156th epoch starting.
# Epoch [157] Loss: 0.3402
# 157th epoch starting.
# Epoch [158] Loss: 0.3948
# 158th epoch starting.
# Epoch [159] Loss: 0.1682
# 159th epoch starting.
# Epoch [160] Loss: 0.2515
# 160th epoch starting.
# Epoch [161] Loss: 0.3032
# 161th epoch starting.
# Epoch [162] Loss: 0.3760
# 162th epoch starting.
# Epoch [163] Loss: 0.3122
# 163th epoch starting.
# Epoch [164] Loss: 0.1355
# 164th epoch starting.
# Epoch [165] Loss: 0.2935
# 165th epoch starting.
# Epoch [166] Loss: 0.2926
# 166th epoch starting.
# Epoch [167] Loss: 0.3975
# 167th epoch starting.
# Epoch [168] Loss: 0.3479
# 168th epoch starting.
# Epoch [169] Loss: 0.1716
# 169th epoch starting.
# Epoch [170] Loss: 0.2229
# 170th epoch starting.
# Epoch [171] Loss: 0.3078
# 171th epoch starting.
# Epoch [172] Loss: 0.3494
# 172th epoch starting.
# Epoch [173] Loss: 0.1959
# 173th epoch starting.
# Epoch [174] Loss: 0.1922
# 174th epoch starting.
# Epoch [175] Loss: 0.3189
# 175th epoch starting.
# Epoch [176] Loss: 0.4721
# 176th epoch starting.
# Epoch [177] Loss: 0.3091
# 177th epoch starting.
# Epoch [178] Loss: 0.4124
# 178th epoch starting.
# Epoch [179] Loss: 0.2403
# 179th epoch starting.
# Epoch [180] Loss: 0.3942
# 180th epoch starting.
# Epoch [181] Loss: 0.3469
# 181th epoch starting.
# Epoch [182] Loss: 0.2066
# 182th epoch starting.
# Epoch [183] Loss: 0.2310
# 183th epoch starting.
# Epoch [184] Loss: 0.2125
# 184th epoch starting.
# Epoch [185] Loss: 0.2606
# 185th epoch starting.
# Epoch [186] Loss: 0.2831
# 186th epoch starting.
# Epoch [187] Loss: 0.1949
# 187th epoch starting.
# Epoch [188] Loss: 0.2613
# 188th epoch starting.
# Epoch [189] Loss: 0.1945
# 189th epoch starting.
# Epoch [190] Loss: 0.5658
# 190th epoch starting.
# Epoch [191] Loss: 0.2137
# 191th epoch starting.
# Epoch [192] Loss: 0.4863
# 192th epoch starting.
# Epoch [193] Loss: 0.4681
# 193th epoch starting.
# Epoch [194] Loss: 0.2114
# 194th epoch starting.
# Epoch [195] Loss: 0.3537
# 195th epoch starting.
# Epoch [196] Loss: 0.1762
# 196th epoch starting.
# Epoch [197] Loss: 0.1463
# 197th epoch starting.
# Epoch [198] Loss: 0.2091
# 198th epoch starting.
# Epoch [199] Loss: 0.3969
# 199th epoch starting.
# Epoch [200] Loss: 0.1350
# Time ellapsed in training is: 2967.545984506607
# [Test set] Average loss: 0.0044, Accuracy: 8677/10000 (86.77%)

# %% [markdown]
# ## GoogLeNet for CIFAR10

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)  # 64 + 128 + 32 + 32 = 256
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        # N x 3 x 32 x 32
        x = self.conv1(x)
        # N x 64 x 32 x 32
        x = self.conv2(x)
        # N x 64 x 32 x 32
        x = self.conv3(x)
        # N x 192 x 28 x 28

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7
        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = torch.flatten(x, 1)
        # N x 1024
        x = self.dropout(x)
        x = self.fc(x)
        # N x 10 (num_classes)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 2.3320
# 1th epoch starting.
# Epoch [2] Loss: 2.0005
# 2th epoch starting.
# Epoch [3] Loss: 1.9520
# 3th epoch starting.
# Epoch [4] Loss: 2.0052
# 4th epoch starting.
# Epoch [5] Loss: 1.7185
# 5th epoch starting.
# Epoch [6] Loss: 1.6784
# 6th epoch starting.
# Epoch [7] Loss: 1.6810
# 7th epoch starting.
# Epoch [8] Loss: 1.5847
# 8th epoch starting.
# Epoch [9] Loss: 1.6538
# 9th epoch starting.
# Epoch [10] Loss: 1.6037
# 10th epoch starting.
# Epoch [11] Loss: 1.5811
# 11th epoch starting.
# Epoch [12] Loss: 1.2541
# 12th epoch starting.
# Epoch [13] Loss: 1.3389
# 13th epoch starting.
# Epoch [14] Loss: 1.3133
# 14th epoch starting.
# Epoch [15] Loss: 1.4574
# 15th epoch starting.
# Epoch [16] Loss: 1.2521
# 16th epoch starting.
# Epoch [17] Loss: 1.3764
# 17th epoch starting.
# Epoch [18] Loss: 1.2681
# 18th epoch starting.
# Epoch [19] Loss: 1.3264
# 19th epoch starting.
# Epoch [20] Loss: 0.9598
# 20th epoch starting.
# Epoch [21] Loss: 1.2644
# 21th epoch starting.
# Epoch [22] Loss: 1.0634
# 22th epoch starting.
# Epoch [23] Loss: 1.4297
# 23th epoch starting.
# Epoch [24] Loss: 1.0247
# 24th epoch starting.
# Epoch [25] Loss: 0.8649
# 25th epoch starting.
# Epoch [26] Loss: 0.8388
# 26th epoch starting.
# Epoch [27] Loss: 1.0086
# 27th epoch starting.
# Epoch [28] Loss: 0.8066
# 28th epoch starting.
# Epoch [29] Loss: 0.6831
# 29th epoch starting.
# Epoch [30] Loss: 0.7590
# 30th epoch starting.
# Epoch [31] Loss: 0.7594
# 31th epoch starting.
# Epoch [32] Loss: 0.8527
# 32th epoch starting.
# Epoch [33] Loss: 0.8227
# 33th epoch starting.
# Epoch [34] Loss: 0.5297
# 34th epoch starting.
# Epoch [35] Loss: 0.6913
# 35th epoch starting.
# Epoch [36] Loss: 0.8176
# 36th epoch starting.
# Epoch [37] Loss: 0.6888
# 37th epoch starting.
# Epoch [38] Loss: 0.5887
# 38th epoch starting.
# Epoch [39] Loss: 0.6278
# 39th epoch starting.
# Epoch [40] Loss: 0.5580
# 40th epoch starting.
# Epoch [41] Loss: 0.4223
# 41th epoch starting.
# Epoch [42] Loss: 0.6831
# 42th epoch starting.
# Epoch [43] Loss: 0.4139
# 43th epoch starting.
# Epoch [44] Loss: 0.5543
# 44th epoch starting.
# Epoch [45] Loss: 0.4941
# 45th epoch starting.
# Epoch [46] Loss: 0.4477
# 46th epoch starting.
# Epoch [47] Loss: 0.3022
# 47th epoch starting.
# Epoch [48] Loss: 0.5611
# 48th epoch starting.
# Epoch [49] Loss: 0.5917
# 49th epoch starting.
# Epoch [50] Loss: 0.4943
# 50th epoch starting.
# Epoch [51] Loss: 0.4304
# 51th epoch starting.
# Epoch [52] Loss: 0.1796
# 52th epoch starting.
# Epoch [53] Loss: 0.3805
# 53th epoch starting.
# Epoch [54] Loss: 0.4037
# 54th epoch starting.
# Epoch [55] Loss: 0.1948
# 55th epoch starting.
# Epoch [56] Loss: 0.3546
# 56th epoch starting.
# Epoch [57] Loss: 0.3881
# 57th epoch starting.
# Epoch [58] Loss: 0.2171
# 58th epoch starting.
# Epoch [59] Loss: 0.3988
# 59th epoch starting.
# Epoch [60] Loss: 0.7470
# 60th epoch starting.
# Epoch [61] Loss: 0.5840
# 61th epoch starting.
# Epoch [62] Loss: 0.3420
# 62th epoch starting.
# Epoch [63] Loss: 0.3334
# 63th epoch starting.
# Epoch [64] Loss: 0.2758
# 64th epoch starting.
# Epoch [65] Loss: 0.3219
# 65th epoch starting.
# Epoch [66] Loss: 0.3611
# 66th epoch starting.
# Epoch [67] Loss: 0.1738
# 67th epoch starting.
# Epoch [68] Loss: 0.1905
# 68th epoch starting.
# Epoch [69] Loss: 0.2060
# 69th epoch starting.
# Epoch [70] Loss: 0.2679
# 70th epoch starting.
# Epoch [71] Loss: 0.2508
# 71th epoch starting.
# Epoch [72] Loss: 0.1611
# 72th epoch starting.
# Epoch [73] Loss: 0.1964
# 73th epoch starting.
# Epoch [74] Loss: 0.3498
# 74th epoch starting.
# Epoch [75] Loss: 0.2988
# 75th epoch starting.
# Epoch [76] Loss: 0.1586
# 76th epoch starting.
# Epoch [77] Loss: 0.2631
# 77th epoch starting.
# Epoch [78] Loss: 0.1580
# 78th epoch starting.
# Epoch [79] Loss: 0.1740
# 79th epoch starting.
# Epoch [80] Loss: 0.2823
# 80th epoch starting.
# Epoch [81] Loss: 0.2473
# 81th epoch starting.
# Epoch [82] Loss: 0.2379
# 82th epoch starting.
# Epoch [83] Loss: 0.1331
# 83th epoch starting.
# Epoch [84] Loss: 0.1661
# 84th epoch starting.
# Epoch [85] Loss: 0.1845
# 85th epoch starting.
# Epoch [86] Loss: 0.1554
# 86th epoch starting.
# Epoch [87] Loss: 0.1572
# 87th epoch starting.
# Epoch [88] Loss: 0.1566
# 88th epoch starting.
# Epoch [89] Loss: 0.1919
# 89th epoch starting.
# Epoch [90] Loss: 0.0995
# 90th epoch starting.
# Epoch [91] Loss: 0.2710
# 91th epoch starting.
# Epoch [92] Loss: 0.3365
# 92th epoch starting.
# Epoch [93] Loss: 0.2943
# 93th epoch starting.
# Epoch [94] Loss: 0.1756
# 94th epoch starting.
# Epoch [95] Loss: 0.1635
# 95th epoch starting.
# Epoch [96] Loss: 0.1200
# 96th epoch starting.
# Epoch [97] Loss: 0.1264
# 97th epoch starting.
# Epoch [98] Loss: 0.1367
# 98th epoch starting.
# Epoch [99] Loss: 0.1158
# 99th epoch starting.
# Epoch [100] Loss: 0.2220
# Time ellapsed in training is: 4248.248762369156
# [Test set] Average loss: 0.0043, Accuracy: 8785/10000 (87.85%)

# %% [markdown]
# ## GoogLeNet with BatchNorm CIFAR10

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool3(x)

        x = self.inception4a(x)
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        x = self.inception4e(x)
        x = self.maxpool4(x)

        x = self.inception5a(x)
        x = self.inception5b(x)
        x = self.avgpool(x)
        
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.BatchNorm2d(out_channels),   #Batch norm here
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 1.2189
# 1th epoch starting.
# Epoch [2] Loss: 0.7970
# 2th epoch starting.
# Epoch [3] Loss: 0.9297
# 3th epoch starting.
# Epoch [4] Loss: 0.4741
# 4th epoch starting.
# Epoch [5] Loss: 0.5163
# 5th epoch starting.
# Epoch [6] Loss: 0.4262
# 6th epoch starting.
# Epoch [7] Loss: 0.4645
# 7th epoch starting.
# Epoch [8] Loss: 0.5391
# 8th epoch starting.
# Epoch [9] Loss: 0.1931
# 9th epoch starting.
# Epoch [10] Loss: 0.4304
# 10th epoch starting.
# Epoch [11] Loss: 0.2508
# 11th epoch starting.
# Epoch [12] Loss: 0.2977
# 12th epoch starting.
# Epoch [13] Loss: 0.3175
# 13th epoch starting.
# Epoch [14] Loss: 0.3184
# 14th epoch starting.
# Epoch [15] Loss: 0.2678
# 15th epoch starting.
# Epoch [16] Loss: 0.3207
# 16th epoch starting.
# Epoch [17] Loss: 0.2194
# 17th epoch starting.
# Epoch [18] Loss: 0.1067
# 18th epoch starting.
# Epoch [19] Loss: 0.1980
# 19th epoch starting.
# Epoch [20] Loss: 0.2995
# 20th epoch starting.
# Epoch [21] Loss: 0.1180
# 21th epoch starting.
# Epoch [22] Loss: 0.0954
# 22th epoch starting.
# Epoch [23] Loss: 0.1840
# 23th epoch starting.
# Epoch [24] Loss: 0.1481
# 24th epoch starting.
# Epoch [25] Loss: 0.1900
# 25th epoch starting.
# Epoch [26] Loss: 0.1190
# 26th epoch starting.
# Epoch [27] Loss: 0.0920
# 27th epoch starting.
# Epoch [28] Loss: 0.1314
# 28th epoch starting.
# Epoch [29] Loss: 0.1146
# 29th epoch starting.
# Epoch [30] Loss: 0.1264
# 30th epoch starting.
# Epoch [31] Loss: 0.0717
# 31th epoch starting.
# Epoch [32] Loss: 0.1462
# 32th epoch starting.
# Epoch [33] Loss: 0.1202
# 33th epoch starting.
# Epoch [34] Loss: 0.1917
# 34th epoch starting.
# Epoch [35] Loss: 0.1068
# 35th epoch starting.
# Epoch [36] Loss: 0.1264
# 36th epoch starting.
# Epoch [37] Loss: 0.0614
# 37th epoch starting.
# Epoch [38] Loss: 0.2544
# 38th epoch starting.
# Epoch [39] Loss: 0.1092
# 39th epoch starting.
# Epoch [40] Loss: 0.0681
# 40th epoch starting.
# Epoch [41] Loss: 0.0967
# 41th epoch starting.
# Epoch [42] Loss: 0.0676
# 42th epoch starting.
# Epoch [43] Loss: 0.1397
# 43th epoch starting.
# Epoch [44] Loss: 0.1258
# 44th epoch starting.
# Epoch [45] Loss: 0.0741
# 45th epoch starting.
# Epoch [46] Loss: 0.1801
# 46th epoch starting.
# Epoch [47] Loss: 0.0710
# 47th epoch starting.
# Epoch [48] Loss: 0.1328
# 48th epoch starting.
# Epoch [49] Loss: 0.1264
# 49th epoch starting.
# Epoch [50] Loss: 0.0801
# 50th epoch starting.
# Epoch [51] Loss: 0.1126
# 51th epoch starting.
# Epoch [52] Loss: 0.0439
# 52th epoch starting.
# Epoch [53] Loss: 0.1416
# 53th epoch starting.
# Epoch [54] Loss: 0.1098
# 54th epoch starting.
# Epoch [55] Loss: 0.0713
# 55th epoch starting.
# Epoch [56] Loss: 0.0924
# 56th epoch starting.
# Epoch [57] Loss: 0.0925
# 57th epoch starting.
# Epoch [58] Loss: 0.0261
# 58th epoch starting.
# Epoch [59] Loss: 0.0974
# 59th epoch starting.
# Epoch [60] Loss: 0.0578
# 60th epoch starting.
# Epoch [61] Loss: 0.0531
# 61th epoch starting.
# Epoch [62] Loss: 0.1240
# 62th epoch starting.
# Epoch [63] Loss: 0.1457
# 63th epoch starting.
# Epoch [64] Loss: 0.0485
# 64th epoch starting.
# Epoch [65] Loss: 0.0860
# 65th epoch starting.
# Epoch [66] Loss: 0.0921
# 66th epoch starting.
# Epoch [67] Loss: 0.1490
# 67th epoch starting.
# Epoch [68] Loss: 0.1342
# 68th epoch starting.
# Epoch [69] Loss: 0.0541
# 69th epoch starting.
# Epoch [70] Loss: 0.0585
# 70th epoch starting.
# Epoch [71] Loss: 0.0980
# 71th epoch starting.
# Epoch [72] Loss: 0.0777
# 72th epoch starting.
# Epoch [73] Loss: 0.0780
# 73th epoch starting.
# Epoch [74] Loss: 0.1253
# 74th epoch starting.
# Epoch [75] Loss: 0.0983
# 75th epoch starting.
# Epoch [76] Loss: 0.0867
# 76th epoch starting.
# Epoch [77] Loss: 0.0245
# 77th epoch starting.
# Epoch [78] Loss: 0.1468
# 78th epoch starting.
# Epoch [79] Loss: 0.0814
# 79th epoch starting.
# Epoch [80] Loss: 0.0311
# 80th epoch starting.
# Epoch [81] Loss: 0.0304
# 81th epoch starting.
# Epoch [82] Loss: 0.1007
# 82th epoch starting.
# Epoch [83] Loss: 0.0565
# 83th epoch starting.
# Epoch [84] Loss: 0.0700
# 84th epoch starting.
# Epoch [85] Loss: 0.0732
# 85th epoch starting.
# Epoch [86] Loss: 0.0469
# 86th epoch starting.
# Epoch [87] Loss: 0.0183
# 87th epoch starting.
# Epoch [88] Loss: 0.1074
# 88th epoch starting.
# Epoch [89] Loss: 0.1222
# 89th epoch starting.
# Epoch [90] Loss: 0.1628
# 90th epoch starting.
# Epoch [91] Loss: 0.0947
# 91th epoch starting.
# Epoch [92] Loss: 0.0439
# 92th epoch starting.
# Epoch [93] Loss: 0.0915
# 93th epoch starting.
# Epoch [94] Loss: 0.0848
# 94th epoch starting.
# Epoch [95] Loss: 0.0345
# 95th epoch starting.
# Epoch [96] Loss: 0.0498
# 96th epoch starting.
# Epoch [97] Loss: 0.0581
# 97th epoch starting.
# Epoch [98] Loss: 0.1319
# 98th epoch starting.
# Epoch [99] Loss: 0.0536
# 99th epoch starting.
# Epoch [100] Loss: 0.0298
# Time ellapsed in training is: 4892.675683021545
# [Test set] Average loss: 0.0043, Accuracy: 8851/10000 (88.51%)
