# %% [markdown]
# <a href="https://colab.research.google.com/github/bangse94/StudyDL/blob/main/googlr03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 12
#
# VGG13 for CIFAR10

# %%
import torch
import torch.nn as nn
import math
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''

# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2
'''

class VGG13(nn.Module) :
    def __init__(self) :
        super(VGG13, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),    # 64 * 32 * 32
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 4096),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(4096, 10),                     # 1 * num_class
                )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()
        
    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output


'''
Step 3
'''
model = VGG13().to(device)
loss_function = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=128, shuffle=True).

import time
start = time.time()
for epoch in range(200) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar_10data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./cifar_10data/cifar-10-python.tar.gz to ./cifar_10data/
# 0th epoch starting.
# Epoch [1] Loss: 2.1117
# 1th epoch starting.
# Epoch [2] Loss: 1.6981
# 2th epoch starting.
# Epoch [3] Loss: 1.6111
# 3th epoch starting.
# Epoch [4] Loss: 1.4036
# 4th epoch starting.
# Epoch [5] Loss: 1.2699
# 5th epoch starting.
# Epoch [6] Loss: 0.8050
# 6th epoch starting.
# Epoch [7] Loss: 1.0679
# 7th epoch starting.
# Epoch [8] Loss: 0.5693
# 8th epoch starting.
# Epoch [9] Loss: 0.7059
# 9th epoch starting.
# Epoch [10] Loss: 0.6427
# 10th epoch starting.
# Epoch [11] Loss: 0.7344
# 11th epoch starting.
# Epoch [12] Loss: 0.7107
# 12th epoch starting.
# Epoch [13] Loss: 0.5643
# 13th epoch starting.
# Epoch [14] Loss: 0.7605
# 14th epoch starting.
# Epoch [15] Loss: 0.5131
# 15th epoch starting.
# Epoch [16] Loss: 0.4694
# 16th epoch starting.
# Epoch [17] Loss: 0.4541
# 17th epoch starting.
# Epoch [18] Loss: 0.3393
# 18th epoch starting.
# Epoch [19] Loss: 0.6356
# 19th epoch starting.
# Epoch [20] Loss: 0.5086
# 20th epoch starting.
# Epoch [21] Loss: 0.4715
# 21th epoch starting.
# Epoch [22] Loss: 0.5550
# 22th epoch starting.
# Epoch [23] Loss: 0.3752
# 23th epoch starting.
# Epoch [24] Loss: 0.4997
# 24th epoch starting.
# Epoch [25] Loss: 0.3908
# 25th epoch starting.
# Epoch [26] Loss: 0.4926
# 26th epoch starting.
# Epoch [27] Loss: 0.2706
# 27th epoch starting.
# Epoch [28] Loss: 0.3932
# 28th epoch starting.
# Epoch [29] Loss: 0.3788
# 29th epoch starting.
# Epoch [30] Loss: 0.4660
# 30th epoch starting.
# Epoch [31] Loss: 0.5969
# 31th epoch starting.
# Epoch [32] Loss: 0.5292
# 32th epoch starting.
# Epoch [33] Loss: 0.4984
# 33th epoch starting.
# Epoch [34] Loss: 0.1947
# 34th epoch starting.
# Epoch [35] Loss: 0.3622
# 35th epoch starting.
# Epoch [36] Loss: 0.2115
# 36th epoch starting.
# Epoch [37] Loss: 0.3634
# 37th epoch starting.
# Epoch [38] Loss: 0.4174
# 38th epoch starting.
# Epoch [39] Loss: 0.2420
# 39th epoch starting.
# Epoch [40] Loss: 0.3274
# 40th epoch starting.
# Epoch [41] Loss: 0.2203
# 41th epoch starting.
# Epoch [42] Loss: 0.1942
# 42th epoch starting.
# Epoch [43] Loss: 0.3520
# 43th epoch starting.
# Epoch [44] Loss: 0.3946
# 44th epoch starting.
# Epoch [45] Loss: 0.2198
# 45th epoch starting.
# Epoch [46] Loss: 0.3533
# 46th epoch starting.
# Epoch [47] Loss: 0.3128
# 47th epoch starting.
# Epoch [48] Loss: 0.2959
# 48th epoch starting.
# Epoch [49] Loss: 0.3625
# 49th epoch starting.
# Epoch [50] Loss: 0.5485
# 50th epoch starting.
# Epoch [51] Loss: 0.3762
# 51th epoch starting.
# Epoch [52] Loss: 0.2683
# 52th epoch starting.
# Epoch [53] Loss: 0.2944
# 53th epoch starting.
# Epoch [54] Loss: 0.3912
# 54th epoch starting.
# Epoch [55] Loss: 0.3318
# 55th epoch starting.
# Epoch [56] Loss: 0.2657
# 56th epoch starting.
# Epoch [57] Loss: 0.1971
# 57th epoch starting.
# Epoch [58] Loss: 0.4568
# 58th epoch starting.
# Epoch [59] Loss: 0.4763
# 59th epoch starting.
# Epoch [60] Loss: 0.2228
# 60th epoch starting.
# Epoch [61] Loss: 0.4987
# 61th epoch starting.
# Epoch [62] Loss: 0.2524
# 62th epoch starting.
# Epoch [63] Loss: 0.2378
# 63th epoch starting.
# Epoch [64] Loss: 0.3945
# 64th epoch starting.
# Epoch [65] Loss: 0.2712
# 65th epoch starting.
# Epoch [66] Loss: 0.1622
# 66th epoch starting.
# Epoch [67] Loss: 0.2282
# 67th epoch starting.
# Epoch [68] Loss: 0.4612
# 68th epoch starting.
# Epoch [69] Loss: 0.4536
# 69th epoch starting.
# Epoch [70] Loss: 0.4880
# 70th epoch starting.
# Epoch [71] Loss: 0.4356
# 71th epoch starting.
# Epoch [72] Loss: 0.3396
# 72th epoch starting.
# Epoch [73] Loss: 0.3682
# 73th epoch starting.
# Epoch [74] Loss: 0.3482
# 74th epoch starting.
# Epoch [75] Loss: 0.4778
# 75th epoch starting.
# Epoch [76] Loss: 0.2819
# 76th epoch starting.
# Epoch [77] Loss: 0.2318
# 77th epoch starting.
# Epoch [78] Loss: 0.2343
# 78th epoch starting.
# Epoch [79] Loss: 0.2633
# 79th epoch starting.
# Epoch [80] Loss: 0.1890
# 80th epoch starting.
# Epoch [81] Loss: 0.3615
# 81th epoch starting.
# Epoch [82] Loss: 0.2514
# 82th epoch starting.
# Epoch [83] Loss: 0.2117
# 83th epoch starting.
# Epoch [84] Loss: 0.1966
# 84th epoch starting.
# Epoch [85] Loss: 0.3644
# 85th epoch starting.
# Epoch [86] Loss: 0.2103
# 86th epoch starting.
# Epoch [87] Loss: 0.2263
# 87th epoch starting.
# Epoch [88] Loss: 0.3048
# 88th epoch starting.
# Epoch [89] Loss: 0.2659
# 89th epoch starting.
# Epoch [90] Loss: 0.2070
# 90th epoch starting.
# Epoch [91] Loss: 0.2753
# 91th epoch starting.
# Epoch [92] Loss: 0.1681
# 92th epoch starting.
# Epoch [93] Loss: 0.0640
# 93th epoch starting.
# Epoch [94] Loss: 0.2779
# 94th epoch starting.
# Epoch [95] Loss: 0.3080
# 95th epoch starting.
# Epoch [96] Loss: 0.3342
# 96th epoch starting.
# Epoch [97] Loss: 0.3571
# 97th epoch starting.
# Epoch [98] Loss: 0.3762
# 98th epoch starting.
# Epoch [99] Loss: 0.2685
# 99th epoch starting.
# Epoch [100] Loss: 0.2747
# 100th epoch starting.
# Epoch [101] Loss: 0.3346
# 101th epoch starting.
# Epoch [102] Loss: 0.2094
# 102th epoch starting.
# Epoch [103] Loss: 0.2895
# 103th epoch starting.
# Epoch [104] Loss: 0.2605
# 104th epoch starting.
# Epoch [105] Loss: 0.3002
# 105th epoch starting.
# Epoch [106] Loss: 0.2913
# 106th epoch starting.
# Epoch [107] Loss: 0.1319
# 107th epoch starting.
# Epoch [108] Loss: 0.3484
# 108th epoch starting.
# Epoch [109] Loss: 0.3868
# 109th epoch starting.
# Epoch [110] Loss: 0.2630
# 110th epoch starting.
# Epoch [111] Loss: 0.2311
# 111th epoch starting.
# Epoch [112] Loss: 0.2939
# 112th epoch starting.
# Epoch [113] Loss: 0.5979
# 113th epoch starting.
# Epoch [114] Loss: 0.3793
# 114th epoch starting.
# Epoch [115] Loss: 0.3768
# 115th epoch starting.
# Epoch [116] Loss: 0.1974
# 116th epoch starting.
# Epoch [117] Loss: 0.1256
# 117th epoch starting.
# Epoch [118] Loss: 0.2273
# 118th epoch starting.
# Epoch [119] Loss: 0.3101
# 119th epoch starting.
# Epoch [120] Loss: 0.3144
# 120th epoch starting.
# Epoch [121] Loss: 0.2093
# 121th epoch starting.
# Epoch [122] Loss: 0.2940
# 122th epoch starting.
# Epoch [123] Loss: 0.2881
# 123th epoch starting.
# Epoch [124] Loss: 0.6664
# 124th epoch starting.
# Epoch [125] Loss: 0.2135
# 125th epoch starting.
# Epoch [126] Loss: 0.2195
# 126th epoch starting.
# Epoch [127] Loss: 0.3083
# 127th epoch starting.
# Epoch [128] Loss: 0.5034
# 128th epoch starting.
# Epoch [129] Loss: 0.3246
# 129th epoch starting.
# Epoch [130] Loss: 0.2279
# 130th epoch starting.
# Epoch [131] Loss: 0.3073
# 131th epoch starting.
# Epoch [132] Loss: 0.3693
# 132th epoch starting.
# Epoch [133] Loss: 0.4103
# 133th epoch starting.
# Epoch [134] Loss: 0.3270
# 134th epoch starting.
# Epoch [135] Loss: 0.3365
# 135th epoch starting.
# Epoch [136] Loss: 0.1407
# 136th epoch starting.
# Epoch [137] Loss: 0.2118
# 137th epoch starting.
# Epoch [138] Loss: 0.2932
# 138th epoch starting.
# Epoch [139] Loss: 0.5099
# 139th epoch starting.
# Epoch [140] Loss: 0.3100
# 140th epoch starting.
# Epoch [141] Loss: 0.6441
# 141th epoch starting.
# Epoch [142] Loss: 0.3215
# 142th epoch starting.
# Epoch [143] Loss: 0.3836
# 143th epoch starting.
# Epoch [144] Loss: 0.2735
# 144th epoch starting.
# Epoch [145] Loss: 0.3692
# 145th epoch starting.
# Epoch [146] Loss: 0.4116
# 146th epoch starting.
# Epoch [147] Loss: 0.3287
# 147th epoch starting.
# Epoch [148] Loss: 0.2970
# 148th epoch starting.
# Epoch [149] Loss: 0.2866
# 149th epoch starting.
# Epoch [150] Loss: 0.1355
# 150th epoch starting.
# Epoch [151] Loss: 0.3059
# 151th epoch starting.
# Epoch [152] Loss: 0.1426
# 152th epoch starting.
# Epoch [153] Loss: 0.1830
# 153th epoch starting.
# Epoch [154] Loss: 0.3579
# 154th epoch starting.
# Epoch [155] Loss: 0.2619
# 155th epoch starting.
# Epoch [156] Loss: 0.2306
# 156th epoch starting.
# Epoch [157] Loss: 0.2971
# 157th epoch starting.
# Epoch [158] Loss: 0.4371
# 158th epoch starting.
# Epoch [159] Loss: 0.2530
# 159th epoch starting.
# Epoch [160] Loss: 0.4025
# 160th epoch starting.
# Epoch [161] Loss: 0.3271
# 161th epoch starting.
# Epoch [162] Loss: 0.2617
# 162th epoch starting.
# Epoch [163] Loss: 0.1999
# 163th epoch starting.
# Epoch [164] Loss: 0.2916
# 164th epoch starting.
# Epoch [165] Loss: 0.2712
# 165th epoch starting.
# Epoch [166] Loss: 0.5965
# 166th epoch starting.
# Epoch [167] Loss: 0.1150
# 167th epoch starting.
# Epoch [168] Loss: 0.3667
# 168th epoch starting.
# Epoch [169] Loss: 0.3507
# 169th epoch starting.
# Epoch [170] Loss: 0.2734
# 170th epoch starting.
# Epoch [171] Loss: 0.3297
# 171th epoch starting.
# Epoch [172] Loss: 0.2706
# 172th epoch starting.
# Epoch [173] Loss: 0.3181
# 173th epoch starting.
# Epoch [174] Loss: 0.2373
# 174th epoch starting.
# Epoch [175] Loss: 0.2802
# 175th epoch starting.
# Epoch [176] Loss: 0.4402
# 176th epoch starting.
# Epoch [177] Loss: 0.4660
# 177th epoch starting.
# Epoch [178] Loss: 0.2737
# 178th epoch starting.
# Epoch [179] Loss: 0.1574
# 179th epoch starting.
# Epoch [180] Loss: 0.1446
# 180th epoch starting.
# Epoch [181] Loss: 0.3692
# 181th epoch starting.
# Epoch [182] Loss: 0.1917
# 182th epoch starting.
# Epoch [183] Loss: 0.3769
# 183th epoch starting.
# Epoch [184] Loss: 0.3068
# 184th epoch starting.
# Epoch [185] Loss: 0.2789
# 185th epoch starting.
# Epoch [186] Loss: 0.2498
# 186th epoch starting.
# Epoch [187] Loss: 0.1411
# 187th epoch starting.
# Epoch [188] Loss: 0.3105
# 188th epoch starting.
# Epoch [189] Loss: 0.1503
# 189th epoch starting.
# Epoch [190] Loss: 0.1498
# 190th epoch starting.
# Epoch [191] Loss: 0.2003
# 191th epoch starting.
# Epoch [192] Loss: 0.3196
# 192th epoch starting.
# Epoch [193] Loss: 0.2095
# 193th epoch starting.
# Epoch [194] Loss: 0.5194
# 194th epoch starting.
# Epoch [195] Loss: 0.3706
# 195th epoch starting.
# Epoch [196] Loss: 0.1943
# 196th epoch starting.
# Epoch [197] Loss: 0.2807
# 197th epoch starting.
# Epoch [198] Loss: 0.1012
# 198th epoch starting.
# Epoch [199] Loss: 0.3072
# 199th epoch starting.
# Epoch [200] Loss: 0.3511
# Time ellapsed in training is: 5255.895607948303
# [Test set] Average loss: 0.0040, Accuracy: 8746/10000 (87.46%)

# %% [markdown]
# ## GoogLeNet for CIFAR10

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)  # 64 + 128 + 32 + 32 = 256
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        # N x 3 x 32 x 32
        x = self.conv1(x)
        # N x 64 x 32 x 32
        x = self.conv2(x)
        # N x 64 x 32 x 32
        x = self.conv3(x)
        # N x 192 x 28 x 28

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7
        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = torch.flatten(x, 1)
        # N x 1024
        x = self.dropout(x)
        x = self.fc(x)
        # N x 10 (num_classes)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-79e01c2a37b4> in <module>()
#     169         train_loss.backward()
#     170
# --> 171         optimizer.step()
#     172
#     173     print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      84
#      85         # Decay the first and second moment running average coefficient
# ---> 86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#      87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#      88         if amsgrad:
#
# KeyboardInterrupt:

# %% [markdown]
# ## GoogLeNet with BatchNorm CIFAR10

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool3(x)

        x = self.inception4a(x)
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        x = self.inception4e(x)
        x = self.maxpool4(x)

        x = self.inception5a(x)
        x = self.inception5b(x)
        x = self.avgpool(x)
        
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.BatchNorm2d(out_channels),   #Batch norm here
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.3, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(50) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 1.5581
# 1th epoch starting.
# Epoch [2] Loss: 1.1063
# 2th epoch starting.
# Epoch [3] Loss: 0.8782
# 3th epoch starting.
# Epoch [4] Loss: 0.7912
# 4th epoch starting.
# Epoch [5] Loss: 0.5165
# 5th epoch starting.
# Epoch [6] Loss: 0.4944
# 6th epoch starting.
# Epoch [7] Loss: 0.4140
# 7th epoch starting.
# Epoch [8] Loss: 0.5359
# 8th epoch starting.
# Epoch [9] Loss: 0.4796
# 9th epoch starting.
# Epoch [10] Loss: 0.4209
# 10th epoch starting.
# Epoch [11] Loss: 0.4242
# 11th epoch starting.
# Epoch [12] Loss: 0.3388
# 12th epoch starting.
# Epoch [13] Loss: 0.2239
# 13th epoch starting.
# Epoch [14] Loss: 0.3628
# 14th epoch starting.
# Epoch [15] Loss: 0.2659
# 15th epoch starting.
# Epoch [16] Loss: 0.2916
# 16th epoch starting.
# Epoch [17] Loss: 0.2564
# 17th epoch starting.
# Epoch [18] Loss: 0.3371
# 18th epoch starting.
# Epoch [19] Loss: 0.3026
# 19th epoch starting.
# Epoch [20] Loss: 0.3820
# 20th epoch starting.
# Epoch [21] Loss: 0.2760
# 21th epoch starting.
# Epoch [22] Loss: 0.2143
# 22th epoch starting.
# Epoch [23] Loss: 0.2290
# 23th epoch starting.
# Epoch [24] Loss: 0.1657
# 24th epoch starting.
# Epoch [25] Loss: 0.2550
# 25th epoch starting.
# Epoch [26] Loss: 0.1648
# 26th epoch starting.
# Epoch [27] Loss: 0.2285
# 27th epoch starting.
# Epoch [28] Loss: 0.3068
# 28th epoch starting.
# Epoch [29] Loss: 0.3333
# 29th epoch starting.
# Epoch [30] Loss: 0.1710
# 30th epoch starting.
# Epoch [31] Loss: 0.2821
# 31th epoch starting.
# Epoch [32] Loss: 0.2339
# 32th epoch starting.
# Epoch [33] Loss: 0.2298
# 33th epoch starting.
# Epoch [34] Loss: 0.2291
# 34th epoch starting.
# Epoch [35] Loss: 0.2611
# 35th epoch starting.
# Epoch [36] Loss: 0.2140
# 36th epoch starting.
# Epoch [37] Loss: 0.2513
# 37th epoch starting.
# Epoch [38] Loss: 0.1501
# 38th epoch starting.
# Epoch [39] Loss: 0.2071
# 39th epoch starting.
# Epoch [40] Loss: 0.1848
# 40th epoch starting.
# Epoch [41] Loss: 0.3244
# 41th epoch starting.
# Epoch [42] Loss: 0.4158
# 42th epoch starting.
# Epoch [43] Loss: 0.1856
# 43th epoch starting.
# Epoch [44] Loss: 0.1343
# 44th epoch starting.
# Epoch [45] Loss: 0.2665
# 45th epoch starting.
# Epoch [46] Loss: 0.2185
# 46th epoch starting.
# Epoch [47] Loss: 0.2265
# 47th epoch starting.
# Epoch [48] Loss: 0.2367
# 48th epoch starting.
# Epoch [49] Loss: 0.2599
# 49th epoch starting.
# Epoch [50] Loss: 0.1647
# Time ellapsed in training is: 7714.93803524971
# [Test set] Average loss: 0.0048, Accuracy: 8466/10000 (84.66%)
