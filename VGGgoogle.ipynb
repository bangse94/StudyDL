# %% [markdown]
# <a href="https://colab.research.google.com/github/bangse94/StudyDL/blob/main/VGGgoogle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 12
#
# VGG13 for CIFAR10

# %%
import torch
import torch.nn as nn
import math
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''

# Image preprocessing modules
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2
'''

class VGG13(nn.Module) :
    def __init__(self) :
        super(VGG13, self).__init__()
        
        self.conv_layer1 = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, padding=1),     # 64 * 32 * 32
                nn.ReLU(),
                nn.Conv2d(64, 64, kernel_size=3, padding=1),    # 64 * 32 * 32
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 64 * 16 * 16
                )
        self.conv_layer2 = nn.Sequential(
                nn.Conv2d(64, 128, kernel_size=3, padding=1),   # 128 * 16 * 16
                nn.ReLU(),
                nn.Conv2d(128, 128, kernel_size=3, padding=1),  # 128 * 16 * 16
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 128 * 8 * 8
                )
        self.conv_layer3 = nn.Sequential(
                nn.Conv2d(128, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.Conv2d(256, 256, kernel_size=3, padding=1),  # 256 * 8 * 8
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2)           # 256 * 4 * 4
                )
        self.conv_layer4 = nn.Sequential(
                nn.Conv2d(256, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.Conv2d(512, 512, kernel_size=3, padding=1),  # 512 * 4 * 4
                nn.ReLU(),
                nn.MaxPool2d(kernel_size=2, stride=2),          # 512 * 2 * 2
                )
        self.fc_layer1 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(512*2*2, 4096),                           # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer2 = nn.Sequential(
                nn.Dropout(),
                nn.Linear(4096, 4096),                          # 1 * 4096
                nn.ReLU()
                )
        self.fc_layer3 = nn.Sequential(
                nn.Linear(4096, 10),                     # 1 * num_class
                )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                m.bias.data.zero_()
        
    def forward(self, x) :
        output = self.conv_layer1(x)
        output = self.conv_layer2(output)
        output = self.conv_layer3(output)
        output = self.conv_layer4(output)
        output = output.view(-1, 512*2*2)
        output = self.fc_layer1(output)
        output = self.fc_layer2(output)
        output = self.fc_layer3(output)
        return output


'''
Step 3
'''
model = VGG13().to(device)
loss_function = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=128, shuffle=True)

import time
start = time.time()
for epoch in range(200) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))

print("Training Time : %H:%M:%S". time.gmtime(end-start))

'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 2.2043
# 1th epoch starting.
# Epoch [2] Loss: 1.9138
# 2th epoch starting.
# Epoch [3] Loss: 1.6821
# 3th epoch starting.
# Epoch [4] Loss: 1.6314
# 4th epoch starting.
# Epoch [5] Loss: 1.3362
# 5th epoch starting.
# Epoch [6] Loss: 1.2162
# 6th epoch starting.
# Epoch [7] Loss: 1.1991
# 7th epoch starting.
# Epoch [8] Loss: 1.0152
# 8th epoch starting.
# Epoch [9] Loss: 1.1098
# 9th epoch starting.
# Epoch [10] Loss: 1.0494
# 10th epoch starting.
# Epoch [11] Loss: 0.9397
# 11th epoch starting.
# Epoch [12] Loss: 0.8587
# 12th epoch starting.
# Epoch [13] Loss: 0.8591
# 13th epoch starting.
# Epoch [14] Loss: 0.7665
# 14th epoch starting.
# Epoch [15] Loss: 0.8241
# 15th epoch starting.
# Epoch [16] Loss: 0.5107
# 16th epoch starting.
# Epoch [17] Loss: 0.6291
# 17th epoch starting.
# Epoch [18] Loss: 0.4829
# 18th epoch starting.
# Epoch [19] Loss: 0.4125
# 19th epoch starting.
# Epoch [20] Loss: 0.6226
# 20th epoch starting.
# Epoch [21] Loss: 0.4966
# 21th epoch starting.
# Epoch [22] Loss: 0.5758
# 22th epoch starting.
# Epoch [23] Loss: 0.6239
# 23th epoch starting.
# Epoch [24] Loss: 0.4471
# 24th epoch starting.
# Epoch [25] Loss: 0.5719
# 25th epoch starting.
# Epoch [26] Loss: 0.3899
# 26th epoch starting.
# Epoch [27] Loss: 0.3267
# 27th epoch starting.
# Epoch [28] Loss: 0.6625
# 28th epoch starting.
# Epoch [29] Loss: 0.2962
# 29th epoch starting.
# Epoch [30] Loss: 0.4325
# 30th epoch starting.
# Epoch [31] Loss: 0.5900
# 31th epoch starting.
# Epoch [32] Loss: 0.4027
# 32th epoch starting.
# Epoch [33] Loss: 0.4336
# 33th epoch starting.
# Epoch [34] Loss: 0.4753
# 34th epoch starting.
# Epoch [35] Loss: 0.3894
# 35th epoch starting.
# Epoch [36] Loss: 0.4507
# 36th epoch starting.
# Epoch [37] Loss: 0.5497
# 37th epoch starting.
# Epoch [38] Loss: 0.3736
# 38th epoch starting.
# Epoch [39] Loss: 0.4392
# 39th epoch starting.
# Epoch [40] Loss: 0.6720
# 40th epoch starting.
# Epoch [41] Loss: 0.3808
# 41th epoch starting.
# Epoch [42] Loss: 0.6170
# 42th epoch starting.
# Epoch [43] Loss: 0.3747
# 43th epoch starting.
# Epoch [44] Loss: 0.4076
# 44th epoch starting.
# Epoch [45] Loss: 0.3898
# 45th epoch starting.
# Epoch [46] Loss: 0.6017
# 46th epoch starting.
# Epoch [47] Loss: 0.4099
# 47th epoch starting.
# Epoch [48] Loss: 0.4339
# 48th epoch starting.
# Epoch [49] Loss: 0.4664
# 49th epoch starting.
# Epoch [50] Loss: 0.2757
# 50th epoch starting.
# Epoch [51] Loss: 0.2785
# 51th epoch starting.
# Epoch [52] Loss: 0.4456
# 52th epoch starting.
# Epoch [53] Loss: 0.3430
# 53th epoch starting.
# Epoch [54] Loss: 0.4160
# 54th epoch starting.
# Epoch [55] Loss: 0.2760
# 55th epoch starting.
# Epoch [56] Loss: 0.3874
# 56th epoch starting.
# Epoch [57] Loss: 0.3164
# 57th epoch starting.
# Epoch [58] Loss: 0.3535
# 58th epoch starting.
# Epoch [59] Loss: 0.2997
# 59th epoch starting.
# Epoch [60] Loss: 0.3205
# 60th epoch starting.
# Epoch [61] Loss: 0.3063
# 61th epoch starting.
# Epoch [62] Loss: 0.3778
# 62th epoch starting.
# Epoch [63] Loss: 0.5727
# 63th epoch starting.
# Epoch [64] Loss: 0.4952
# 64th epoch starting.
# Epoch [65] Loss: 0.3534
# 65th epoch starting.
# Epoch [66] Loss: 0.3866
# 66th epoch starting.
# Epoch [67] Loss: 0.2202
# 67th epoch starting.
# Epoch [68] Loss: 0.5761
# 68th epoch starting.
# Epoch [69] Loss: 0.2262
# 69th epoch starting.
# Epoch [70] Loss: 0.3217
# 70th epoch starting.
# Epoch [71] Loss: 0.2727
# 71th epoch starting.
# Epoch [72] Loss: 0.2440
# 72th epoch starting.
# Epoch [73] Loss: 0.2079
# 73th epoch starting.
# Epoch [74] Loss: 0.1627
# 74th epoch starting.
# Epoch [75] Loss: 0.5516
# 75th epoch starting.
# Epoch [76] Loss: 0.3142
# 76th epoch starting.
# Epoch [77] Loss: 0.2323
# 77th epoch starting.
# Epoch [78] Loss: 0.4137
# 78th epoch starting.
# Epoch [79] Loss: 0.3838
# 79th epoch starting.
# Epoch [80] Loss: 0.4283
# 80th epoch starting.
# Epoch [81] Loss: 0.3759
# 81th epoch starting.
# Epoch [82] Loss: 0.2690
# 82th epoch starting.
# Epoch [83] Loss: 0.3887
# 83th epoch starting.
# Epoch [84] Loss: 0.3311
# 84th epoch starting.
# Epoch [85] Loss: 0.4675
# 85th epoch starting.
# Epoch [86] Loss: 0.2677
# 86th epoch starting.
# Epoch [87] Loss: 0.3697
# 87th epoch starting.
# Epoch [88] Loss: 0.2661
# 88th epoch starting.
# Epoch [89] Loss: 0.3023
# 89th epoch starting.
# Epoch [90] Loss: 0.2642
# 90th epoch starting.
# Epoch [91] Loss: 0.2603
# 91th epoch starting.
# Epoch [92] Loss: 0.3140
# 92th epoch starting.
# Epoch [93] Loss: 0.2582
# 93th epoch starting.
# Epoch [94] Loss: 0.1769
# 94th epoch starting.
# Epoch [95] Loss: 0.4040
# 95th epoch starting.
# Epoch [96] Loss: 0.2516
# 96th epoch starting.
# Epoch [97] Loss: 0.2611
# 97th epoch starting.
# Epoch [98] Loss: 0.2509
# 98th epoch starting.
# Epoch [99] Loss: 0.2559
# 99th epoch starting.
# Epoch [100] Loss: 0.3736
# 100th epoch starting.
# Epoch [101] Loss: 0.2004
# 101th epoch starting.
# Epoch [102] Loss: 0.4693
# 102th epoch starting.
# Epoch [103] Loss: 0.2608
# 103th epoch starting.
# Epoch [104] Loss: 0.3215
# 104th epoch starting.
# Epoch [105] Loss: 0.3205
# 105th epoch starting.
# Epoch [106] Loss: 0.3488
# 106th epoch starting.
# Epoch [107] Loss: 0.3465
# 107th epoch starting.
# Epoch [108] Loss: 0.5606
# 108th epoch starting.
# Epoch [109] Loss: 0.2261
# 109th epoch starting.
# Epoch [110] Loss: 0.3519
# 110th epoch starting.
# Epoch [111] Loss: 0.2490
# 111th epoch starting.
# Epoch [112] Loss: 0.3571
# 112th epoch starting.
# Epoch [113] Loss: 0.2370
# 113th epoch starting.
# Epoch [114] Loss: 0.3623
# 114th epoch starting.
# Epoch [115] Loss: 0.2768
# 115th epoch starting.
# Epoch [116] Loss: 0.3475
# 116th epoch starting.
# Epoch [117] Loss: 0.2811
# 117th epoch starting.
# Epoch [118] Loss: 0.2851
# 118th epoch starting.
# Epoch [119] Loss: 0.1499
# 119th epoch starting.
# Epoch [120] Loss: 0.2958
# 120th epoch starting.
# Epoch [121] Loss: 0.3332
# 121th epoch starting.
# Epoch [122] Loss: 0.3097
# 122th epoch starting.
# Epoch [123] Loss: 0.1879
# 123th epoch starting.
# Epoch [124] Loss: 0.2183
# 124th epoch starting.
# Epoch [125] Loss: 0.2830
# 125th epoch starting.
# Epoch [126] Loss: 0.3077
# 126th epoch starting.
# Epoch [127] Loss: 0.2783
# 127th epoch starting.
# Epoch [128] Loss: 0.2619
# 128th epoch starting.
# Epoch [129] Loss: 0.3673
# 129th epoch starting.
# Epoch [130] Loss: 0.2614
# 130th epoch starting.
# Epoch [131] Loss: 0.3730
# 131th epoch starting.
# Epoch [132] Loss: 0.2373
# 132th epoch starting.
# Epoch [133] Loss: 0.2900
# 133th epoch starting.
# Epoch [134] Loss: 0.2263
# 134th epoch starting.
# Epoch [135] Loss: 0.5604
# 135th epoch starting.
# Epoch [136] Loss: 0.1550
# 136th epoch starting.
# Epoch [137] Loss: 0.3723
# 137th epoch starting.
# Epoch [138] Loss: 0.2773
# 138th epoch starting.
# Epoch [139] Loss: 0.2933
# 139th epoch starting.
# Epoch [140] Loss: 0.3389
# 140th epoch starting.
# Epoch [141] Loss: 0.2559
# 141th epoch starting.
# Epoch [142] Loss: 0.2244
# 142th epoch starting.
# Epoch [143] Loss: 0.1756
# 143th epoch starting.
# Epoch [144] Loss: 0.1922
# 144th epoch starting.
# Epoch [145] Loss: 0.2620
# 145th epoch starting.
# Epoch [146] Loss: 0.3685
# 146th epoch starting.
# Epoch [147] Loss: 0.1840
# 147th epoch starting.
# Epoch [148] Loss: 0.2516
# 148th epoch starting.
# Epoch [149] Loss: 0.3255
# 149th epoch starting.
# Epoch [150] Loss: 0.3534
# 150th epoch starting.
# Epoch [151] Loss: 0.2758
# 151th epoch starting.
# Epoch [152] Loss: 0.3454
# 152th epoch starting.
# Epoch [153] Loss: 0.3278
# 153th epoch starting.
# Epoch [154] Loss: 0.3588
# 154th epoch starting.
# Epoch [155] Loss: 0.2156
# 155th epoch starting.
# Epoch [156] Loss: 0.1580
# 156th epoch starting.
# Epoch [157] Loss: 0.3094
# 157th epoch starting.
# Epoch [158] Loss: 0.2891
# 158th epoch starting.
# Epoch [159] Loss: 0.1958
# 159th epoch starting.
# Epoch [160] Loss: 0.1904
# 160th epoch starting.
# Epoch [161] Loss: 0.2801
# 161th epoch starting.
# Epoch [162] Loss: 0.2131
# 162th epoch starting.
# Epoch [163] Loss: 0.2892
# 163th epoch starting.
# Epoch [164] Loss: 0.4499
# 164th epoch starting.
# Epoch [165] Loss: 0.1147
# 165th epoch starting.
# Epoch [166] Loss: 0.1998
# 166th epoch starting.
# Epoch [167] Loss: 0.1245
# 167th epoch starting.
# Epoch [168] Loss: 0.2210
# 168th epoch starting.
# Epoch [169] Loss: 0.2524
# 169th epoch starting.
# Epoch [170] Loss: 0.1865
# 170th epoch starting.
# Epoch [171] Loss: 0.2271
# 171th epoch starting.
# Epoch [172] Loss: 0.4247
# 172th epoch starting.
# Epoch [173] Loss: 0.1725
# 173th epoch starting.
# Epoch [174] Loss: 0.2999
# 174th epoch starting.
# Epoch [175] Loss: 0.2170
# 175th epoch starting.
# Epoch [176] Loss: 0.1799
# 176th epoch starting.
# Epoch [177] Loss: 0.2130
# 177th epoch starting.
# Epoch [178] Loss: 0.3733
# 178th epoch starting.
# Epoch [179] Loss: 0.2985
# 179th epoch starting.
# Epoch [180] Loss: 0.2472
# 180th epoch starting.
# Epoch [181] Loss: 0.2294
# 181th epoch starting.
# Epoch [182] Loss: 0.3096
# 182th epoch starting.
# Epoch [183] Loss: 0.2112
# 183th epoch starting.
# Epoch [184] Loss: 0.1455
# 184th epoch starting.
# Epoch [185] Loss: 0.1370
# 185th epoch starting.
# Epoch [186] Loss: 0.3161
# 186th epoch starting.
# Epoch [187] Loss: 0.2762
# 187th epoch starting.
# Epoch [188] Loss: 0.1828
# 188th epoch starting.
# Epoch [189] Loss: 0.1409
# 189th epoch starting.
# Epoch [190] Loss: 0.2793
# 190th epoch starting.
# Epoch [191] Loss: 0.2572
# 191th epoch starting.
# Epoch [192] Loss: 0.3033
# 192th epoch starting.
# Epoch [193] Loss: 0.1548
# 193th epoch starting.
# Epoch [194] Loss: 0.1797
# 194th epoch starting.
# Epoch [195] Loss: 0.3286
# 195th epoch starting.
# Epoch [196] Loss: 0.1471
# 196th epoch starting.
# Epoch [197] Loss: 0.4338
# 197th epoch starting.
# Epoch [198] Loss: 0.2096
# 198th epoch starting.
# Epoch [199] Loss: 0.3300
# 199th epoch starting.
# Epoch [200] Loss: 0.2228
# Time ellapsed in training is: 5321.017961502075
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c7bc4ea14926> in <module>()
#     134 print("Time ellapsed in training is: {}".format(end - start))
#     135
# --> 136 print("Training Time : %H:%M:%S". time.gmtime(end-start))
#     137
#     138 '''
#
# AttributeError: 'str' object has no attribute 'time'

# %% [markdown]
# ## GoogLeNet for CIFAR10

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)  # 64 + 128 + 32 + 32 = 256
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        # N x 3 x 32 x 32
        x = self.conv1(x)
        # N x 64 x 32 x 32
        x = self.conv2(x)
        # N x 64 x 32 x 32
        x = self.conv3(x)
        # N x 192 x 28 x 28

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7
        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = torch.flatten(x, 1)
        # N x 1024
        x = self.dropout(x)
        x = self.fc(x)
        # N x 10 (num_classes)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 2.2639
# 1th epoch starting.
# Epoch [2] Loss: 1.9377
# 2th epoch starting.
# Epoch [3] Loss: 1.8957
# 3th epoch starting.
# Epoch [4] Loss: 1.8470
# 4th epoch starting.
# Epoch [5] Loss: 1.9300
# 5th epoch starting.
# Epoch [6] Loss: 1.6088
# 6th epoch starting.
# Epoch [7] Loss: 1.7900
# 7th epoch starting.
# Epoch [8] Loss: 1.5765
# 8th epoch starting.
# Epoch [9] Loss: 1.6309
# 9th epoch starting.
# Epoch [10] Loss: 1.3813
# 10th epoch starting.
# Epoch [11] Loss: 1.2910
# 11th epoch starting.
# Epoch [12] Loss: 1.4910
# 12th epoch starting.
# Epoch [13] Loss: 1.2687
# 13th epoch starting.
# Epoch [14] Loss: 1.1695
# 14th epoch starting.
# Epoch [15] Loss: 1.4188
# 15th epoch starting.
# Epoch [16] Loss: 1.2343
# 16th epoch starting.
# Epoch [17] Loss: 1.3205
# 17th epoch starting.
# Epoch [18] Loss: 1.4026
# 18th epoch starting.
# Epoch [19] Loss: 0.9462
# 19th epoch starting.
# Epoch [20] Loss: 0.8126
# 20th epoch starting.
# Epoch [21] Loss: 0.9225
# 21th epoch starting.
# Epoch [22] Loss: 0.9850
# 22th epoch starting.
# Epoch [23] Loss: 1.1631
# 23th epoch starting.
# Epoch [24] Loss: 1.0256
# 24th epoch starting.
# Epoch [25] Loss: 0.9437
# 25th epoch starting.
# Epoch [26] Loss: 0.9535
# 26th epoch starting.
# Epoch [27] Loss: 0.9194
# 27th epoch starting.
# Epoch [28] Loss: 1.1363
# 28th epoch starting.
# Epoch [29] Loss: 0.9299
# 29th epoch starting.
# Epoch [30] Loss: 0.8454
# 30th epoch starting.
# Epoch [31] Loss: 0.9446
# 31th epoch starting.
# Epoch [32] Loss: 0.8158
# 32th epoch starting.
# Epoch [33] Loss: 0.6574
# 33th epoch starting.
# Epoch [34] Loss: 0.8693
# 34th epoch starting.
# Epoch [35] Loss: 0.6481
# 35th epoch starting.
# Epoch [36] Loss: 0.6801
# 36th epoch starting.
# Epoch [37] Loss: 0.7408
# 37th epoch starting.
# Epoch [38] Loss: 0.5675
# 38th epoch starting.
# Epoch [39] Loss: 0.4982
# 39th epoch starting.
# Epoch [40] Loss: 0.9392
# 40th epoch starting.
# Epoch [41] Loss: 0.6104
# 41th epoch starting.
# Epoch [42] Loss: 0.5620
# 42th epoch starting.
# Epoch [43] Loss: 0.5158
# 43th epoch starting.
# Epoch [44] Loss: 0.5305
# 44th epoch starting.
# Epoch [45] Loss: 0.5582
# 45th epoch starting.
# Epoch [46] Loss: 0.5192
# 46th epoch starting.
# Epoch [47] Loss: 0.6213
# 47th epoch starting.
# Epoch [48] Loss: 0.5972
# 48th epoch starting.
# Epoch [49] Loss: 0.5634
# 49th epoch starting.
# Epoch [50] Loss: 0.5685
# 50th epoch starting.
# Epoch [51] Loss: 0.3920
# 51th epoch starting.
# Epoch [52] Loss: 0.6400
# 52th epoch starting.
# Epoch [53] Loss: 0.5925
# 53th epoch starting.
# Epoch [54] Loss: 0.3719
# 54th epoch starting.
# Epoch [55] Loss: 0.4549
# 55th epoch starting.
# Epoch [56] Loss: 0.4853
# 56th epoch starting.
# Epoch [57] Loss: 0.4016
# 57th epoch starting.
# Epoch [58] Loss: 0.4569
# 58th epoch starting.
# Epoch [59] Loss: 0.2845
# 59th epoch starting.
# Epoch [60] Loss: 0.2335
# 60th epoch starting.
# Epoch [61] Loss: 0.3346
# 61th epoch starting.
# Epoch [62] Loss: 0.4178
# 62th epoch starting.
# Epoch [63] Loss: 0.4807
# 63th epoch starting.
# Epoch [64] Loss: 0.3539
# 64th epoch starting.
# Epoch [65] Loss: 0.2574
# 65th epoch starting.
# Epoch [66] Loss: 0.2346
# 66th epoch starting.
# Epoch [67] Loss: 0.3409
# 67th epoch starting.
# Epoch [68] Loss: 0.2400
# 68th epoch starting.
# Epoch [69] Loss: 0.2105
# 69th epoch starting.
# Epoch [70] Loss: 0.3277
# 70th epoch starting.
# Epoch [71] Loss: 0.3122
# 71th epoch starting.
# Epoch [72] Loss: 0.2584
# 72th epoch starting.
# Epoch [73] Loss: 0.3545
# 73th epoch starting.
# Epoch [74] Loss: 0.2783
# 74th epoch starting.
# Epoch [75] Loss: 0.2108
# 75th epoch starting.
# Epoch [76] Loss: 0.2256
# 76th epoch starting.
# Epoch [77] Loss: 0.2780
# 77th epoch starting.
# Epoch [78] Loss: 0.1460
# 78th epoch starting.
# Epoch [79] Loss: 0.1612
# 79th epoch starting.
# Epoch [80] Loss: 0.2963
# 80th epoch starting.
# Epoch [81] Loss: 0.3506
# 81th epoch starting.
# Epoch [82] Loss: 0.1634
# 82th epoch starting.
# Epoch [83] Loss: 0.1594
# 83th epoch starting.
# Epoch [84] Loss: 0.2915
# 84th epoch starting.
# Epoch [85] Loss: 0.2295
# 85th epoch starting.
# Epoch [86] Loss: 0.0733
# 86th epoch starting.
# Epoch [87] Loss: 0.1349
# 87th epoch starting.
# Epoch [88] Loss: 0.1256
# 88th epoch starting.
# Epoch [89] Loss: 0.2889
# 89th epoch starting.
# Epoch [90] Loss: 0.2816
# 90th epoch starting.
# Epoch [91] Loss: 0.3078
# 91th epoch starting.
# Epoch [92] Loss: 0.6411
# 92th epoch starting.
# Epoch [93] Loss: 0.3656
# 93th epoch starting.
# Epoch [94] Loss: 0.2338
# 94th epoch starting.
# Epoch [95] Loss: 0.2020
# 95th epoch starting.
# Epoch [96] Loss: 0.2832
# 96th epoch starting.
# Epoch [97] Loss: 0.3860
# 97th epoch starting.
# Epoch [98] Loss: 0.1647
# 98th epoch starting.
# Epoch [99] Loss: 0.1763
# 99th epoch starting.
# Epoch [100] Loss: 0.1732
# Time ellapsed in training is: 7174.51455116272
# [Test set] Average loss: 0.0045, Accuracy: 8728/10000 (87.28%)

# %% [markdown]
# ## GoogLeNet with BatchNorm CIFAR10

# %%
import torch
import torch.nn as nn
from torch.optim import Optimizer
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import transforms

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

'''
Step 1:
'''
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

train_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                 train=True, 
                                 transform=transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='./cifar_10data/',
                                train=False, 
                                transform=transforms.ToTensor())
    
'''
Step 2:
'''
class GoogLeNet(nn.Module):

    def __init__(self):
        super(GoogLeNet, self).__init__()        

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, padding=3)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=5)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)


        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, 10)
        
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                torch.nn.init.xavier_uniform_(m.weight)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)

        x = self.inception3a(x)
        x = self.inception3b(x)
        x = self.maxpool3(x)

        x = self.inception4a(x)
        x = self.inception4b(x)
        x = self.inception4c(x)
        x = self.inception4d(x)
        x = self.inception4e(x)
        x = self.maxpool4(x)

        x = self.inception5a(x)
        x = self.inception5b(x)
        x = self.avgpool(x)
        
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc(x)
        return x

class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        
        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=5, padding=2)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        return torch.cat([branch1, branch2, branch3, branch4], 1)


class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Sequential(
                            nn.Conv2d(in_channels, out_channels, **kwargs),
                            nn.BatchNorm2d(out_channels),   #Batch norm here
                            nn.ReLU()
                            )
    def forward(self, x):
        return self.conv(x)
    


'''
Step 3
'''
model = GoogLeNet().to(device)
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, weight_decay=5e-4)

'''
Step 4
'''
model.train()
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)

import time
start = time.time()
for epoch in range(100) :
    print("{}th epoch starting.".format(epoch))
    for i, (images, labels) in enumerate(train_loader) :
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        train_loss = loss_function(model(images), labels)
        train_loss.backward()

        optimizer.step()

    print ("Epoch [{}] Loss: {:.4f}".format(epoch+1, train_loss.item()))

end = time.time()
print("Time ellapsed in training is: {}".format(end - start))


'''
Step 5
'''
model.eval()
test_loss, correct, total = 0, 0, 0

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=100, shuffle=False)
with torch.no_grad():  #using context manager
    for images, labels in test_loader :
        images, labels = images.to(device), labels.to(device)

        output = model(images)
        test_loss += loss_function(output, labels).item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()

        total += labels.size(0)

print('[Test set] Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        test_loss /total, correct, total,
        100. * correct / total))
# Out:
# Files already downloaded and verified
# 0th epoch starting.
# Epoch [1] Loss: 1.3556
# 1th epoch starting.
# Epoch [2] Loss: 1.0016
# 2th epoch starting.
# Epoch [3] Loss: 0.8536
# 3th epoch starting.
# Epoch [4] Loss: 0.6516
# 4th epoch starting.
# Epoch [5] Loss: 0.4868
# 5th epoch starting.
# Epoch [6] Loss: 0.3415
# 6th epoch starting.
# Epoch [7] Loss: 0.3197
# 7th epoch starting.
# Epoch [8] Loss: 0.3560
# 8th epoch starting.
# Epoch [9] Loss: 0.3828
# 9th epoch starting.
# Epoch [10] Loss: 0.4011
# 10th epoch starting.
# Epoch [11] Loss: 0.3260
# 11th epoch starting.
# Epoch [12] Loss: 0.2618
# 12th epoch starting.
# Epoch [13] Loss: 0.2623
# 13th epoch starting.
# Epoch [14] Loss: 0.2755
# 14th epoch starting.
# Epoch [15] Loss: 0.3459
# 15th epoch starting.
# Epoch [16] Loss: 0.2778
# 16th epoch starting.
# Epoch [17] Loss: 0.2131
# 17th epoch starting.
# Epoch [18] Loss: 0.3055
# 18th epoch starting.
# Epoch [19] Loss: 0.1537
# 19th epoch starting.
# Epoch [20] Loss: 0.0999
# 20th epoch starting.
# Epoch [21] Loss: 0.2503
# 21th epoch starting.
# Epoch [22] Loss: 0.1957
# 22th epoch starting.
# Epoch [23] Loss: 0.1567
# 23th epoch starting.
# Epoch [24] Loss: 0.2063
# 24th epoch starting.
# Epoch [25] Loss: 0.0958
# 25th epoch starting.
# Epoch [26] Loss: 0.0811
# 26th epoch starting.
# Epoch [27] Loss: 0.1389
# 27th epoch starting.
# Epoch [28] Loss: 0.1160
# 28th epoch starting.
# Epoch [29] Loss: 0.2026
# 29th epoch starting.
# Epoch [30] Loss: 0.1244
# 30th epoch starting.
# Epoch [31] Loss: 0.0889
# 31th epoch starting.
# Epoch [32] Loss: 0.0641
# 32th epoch starting.
# Epoch [33] Loss: 0.1299
# 33th epoch starting.
# Epoch [34] Loss: 0.1237
# 34th epoch starting.
# Epoch [35] Loss: 0.0647
# 35th epoch starting.
# Epoch [36] Loss: 0.1111
# 36th epoch starting.
# Epoch [37] Loss: 0.1146
# 37th epoch starting.
# Epoch [38] Loss: 0.0665
# 38th epoch starting.
# Epoch [39] Loss: 0.1160
# 39th epoch starting.
# Epoch [40] Loss: 0.1581
# 40th epoch starting.
# Epoch [41] Loss: 0.1007
# 41th epoch starting.
# Epoch [42] Loss: 0.0497
# 42th epoch starting.
# Epoch [43] Loss: 0.0371
# 43th epoch starting.
# Epoch [44] Loss: 0.0768
# 44th epoch starting.
# Epoch [45] Loss: 0.0543
# 45th epoch starting.
# Epoch [46] Loss: 0.0976
# 46th epoch starting.
# Epoch [47] Loss: 0.0502
# 47th epoch starting.
# Epoch [48] Loss: 0.1551
# 48th epoch starting.
# Epoch [49] Loss: 0.0827
# 49th epoch starting.
# Epoch [50] Loss: 0.1055
# 50th epoch starting.
# Epoch [51] Loss: 0.1577
# 51th epoch starting.
# Epoch [52] Loss: 0.0821
# 52th epoch starting.
# Epoch [53] Loss: 0.0847
# 53th epoch starting.
# Epoch [54] Loss: 0.1028
# 54th epoch starting.
# Epoch [55] Loss: 0.0845
# 55th epoch starting.
# Epoch [56] Loss: 0.0814
# 56th epoch starting.
# Epoch [57] Loss: 0.0833
# 57th epoch starting.
# Epoch [58] Loss: 0.1108
# 58th epoch starting.
# Epoch [59] Loss: 0.1267
# 59th epoch starting.
# Epoch [60] Loss: 0.1371
# 60th epoch starting.
# Epoch [61] Loss: 0.0947
# 61th epoch starting.
# Epoch [62] Loss: 0.1374
# 62th epoch starting.
# Epoch [63] Loss: 0.0665
# 63th epoch starting.
# Epoch [64] Loss: 0.1066
# 64th epoch starting.
# Epoch [65] Loss: 0.0788
# 65th epoch starting.
# Epoch [66] Loss: 0.0944
# 66th epoch starting.
# Epoch [67] Loss: 0.0541
# 67th epoch starting.
# Epoch [68] Loss: 0.1057
# 68th epoch starting.
# Epoch [69] Loss: 0.1278
# 69th epoch starting.
# Epoch [70] Loss: 0.0634
# 70th epoch starting.
# Epoch [71] Loss: 0.0315
# 71th epoch starting.
# Epoch [72] Loss: 0.1361
# 72th epoch starting.
# Epoch [73] Loss: 0.0487
# 73th epoch starting.
# Epoch [74] Loss: 0.1465
# 74th epoch starting.
# Epoch [75] Loss: 0.0442
# 75th epoch starting.
# Epoch [76] Loss: 0.0595
# 76th epoch starting.
# Epoch [77] Loss: 0.1443
# 77th epoch starting.
# Epoch [78] Loss: 0.0728
# 78th epoch starting.
# Epoch [79] Loss: 0.0846
# 79th epoch starting.
# Epoch [80] Loss: 0.0924
# 80th epoch starting.
# Epoch [81] Loss: 0.0924
# 81th epoch starting.
# Epoch [82] Loss: 0.0758
# 82th epoch starting.
# Epoch [83] Loss: 0.0511
# 83th epoch starting.
# Epoch [84] Loss: 0.1416
# 84th epoch starting.
# Epoch [85] Loss: 0.0999
# 85th epoch starting.
# Epoch [86] Loss: 0.1032
# 86th epoch starting.
# Epoch [87] Loss: 0.0479
# 87th epoch starting.
# Epoch [88] Loss: 0.0925
# 88th epoch starting.
# Epoch [89] Loss: 0.0760
# 89th epoch starting.
# Epoch [90] Loss: 0.0498
# 90th epoch starting.
# Epoch [91] Loss: 0.0964
# 91th epoch starting.
# Epoch [92] Loss: 0.0629
# 92th epoch starting.
# Epoch [93] Loss: 0.0651
# 93th epoch starting.
# Epoch [94] Loss: 0.0354
# 94th epoch starting.
# Epoch [95] Loss: 0.1460
# 95th epoch starting.
# Epoch [96] Loss: 0.1071
# 96th epoch starting.
# Epoch [97] Loss: 0.0803
# 97th epoch starting.
# Epoch [98] Loss: 0.0751
# 98th epoch starting.
# Epoch [99] Loss: 0.0906
# 99th epoch starting.
# Epoch [100] Loss: 0.0803
# Time ellapsed in training is: 8126.175984621048
# [Test set] Average loss: 0.0072, Accuracy: 8222/10000 (82.22%)
